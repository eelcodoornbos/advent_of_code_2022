# %%
from anytree import Node, RenderTree, PreOrderIter, PostOrderIter, Walker

# %%
with open('real_input.txt', 'r') as fh:
    text = fh.read()
    lines = text.split('\n')

def parse_input(lines):
    root = Node({'dirname': '/', 'size': 0})
    parent = root
    w = Walker()
    ls_mode = False
    for line in lines:
        if line.startswith('$ cd /'):
            ls_mode = False
            parent = root
        elif line.startswith('$ cd'):
            ls_mode = False
            dirname = line[5:]
            if dirname == '..':
                parent = parent.parent
            else:
                prev_parent = parent
                parent = Node({'dirname': dirname, 'size': 0}, parent=prev_parent)
        elif line.startswith('$ ls'):
            ls_mode = True
        elif ls_mode:
            if len(line) > 0 and not line.startswith('dir '):
                (size, name) = line.split()
                new_file = Node({'filename': name, 'size': int(size)}, parent=parent)
                parentnode = new_file.parent
                while parentnode:
                    parentnode.name['size'] += int(size)
                    print("Adding ", size, " to ", parentnode.name['dirname'], " resulting in ", parentnode.name['size'])
                    parentnode = parentnode.parent
        else:
            ls_mode = False
            print("unknown line: ", line)
    return root

root = parse_input(lines)
# Out:
# Adding  82227  to  mnm  resulting in  82227
# Adding  82227  to  cwdpn  resulting in  82227
# Adding  82227  to  /  resulting in  82227
# Adding  114478  to  plldwn  resulting in  114478
# Adding  114478  to  mnm  resulting in  196705
# Adding  114478  to  cwdpn  resulting in  196705
# Adding  114478  to  /  resulting in  196705
# Adding  58874  to  plldwn  resulting in  173352
# Adding  58874  to  mnm  resulting in  255579
# Adding  58874  to  cwdpn  resulting in  255579
# Adding  58874  to  /  resulting in  255579
# Adding  247491  to  plldwn  resulting in  420843
# Adding  247491  to  mnm  resulting in  503070
# Adding  247491  to  cwdpn  resulting in  503070
# Adding  247491  to  /  resulting in  503070
# Adding  114552  to  plldwn  resulting in  535395
# Adding  114552  to  mnm  resulting in  617622
# Adding  114552  to  cwdpn  resulting in  617622
# Adding  114552  to  /  resulting in  617622
# Adding  269910  to  prwm  resulting in  269910
# Adding  269910  to  plldwn  resulting in  805305
# Adding  269910  to  mnm  resulting in  887532
# Adding  269910  to  cwdpn  resulting in  887532
# Adding  269910  to  /  resulting in  887532
# Adding  65341  to  rtpjd  resulting in  65341
# Adding  65341  to  mnm  resulting in  952873
# Adding  65341  to  cwdpn  resulting in  952873
# Adding  65341  to  /  resulting in  952873
# Adding  99117  to  pnrbvd  resulting in  99117
# Adding  99117  to  rtpjd  resulting in  164458
# Adding  99117  to  mnm  resulting in  1051990
# Adding  99117  to  cwdpn  resulting in  1051990
# Adding  99117  to  /  resulting in  1051990
# Adding  192167  to  shvplq  resulting in  192167
# Adding  192167  to  mnm  resulting in  1244157
# Adding  192167  to  cwdpn  resulting in  1244157
# Adding  192167  to  /  resulting in  1244157
# Adding  182737  to  shvplq  resulting in  374904
# Adding  182737  to  mnm  resulting in  1426894
# Adding  182737  to  cwdpn  resulting in  1426894
# Adding  182737  to  /  resulting in  1426894
# Adding  175694  to  shvplq  resulting in  550598
# Adding  175694  to  mnm  resulting in  1602588
# Adding  175694  to  cwdpn  resulting in  1602588
# Adding  175694  to  /  resulting in  1602588
# Adding  93278  to  shvplq  resulting in  643876
# Adding  93278  to  mnm  resulting in  1695866
# Adding  93278  to  cwdpn  resulting in  1695866
# Adding  93278  to  /  resulting in  1695866
# Adding  59203  to  nmsvc  resulting in  59203
# Adding  59203  to  cwdpn  resulting in  1755069
# Adding  59203  to  /  resulting in  1755069
# Adding  49699  to  nmsvc  resulting in  108902
# Adding  49699  to  cwdpn  resulting in  1804768
# Adding  49699  to  /  resulting in  1804768
# Adding  221657  to  nmsvc  resulting in  330559
# Adding  221657  to  cwdpn  resulting in  2026425
# Adding  221657  to  /  resulting in  2026425
# Adding  45989  to  nmsvc  resulting in  376548
# Adding  45989  to  cwdpn  resulting in  2072414
# Adding  45989  to  /  resulting in  2072414
# Adding  181885  to  bjnvmpc  resulting in  181885
# Adding  181885  to  nmsvc  resulting in  558433
# Adding  181885  to  cwdpn  resulting in  2254299
# Adding  181885  to  /  resulting in  2254299
# Adding  236177  to  gfjts  resulting in  236177
# Adding  236177  to  bjnvmpc  resulting in  418062
# Adding  236177  to  nmsvc  resulting in  794610
# Adding  236177  to  cwdpn  resulting in  2490476
# Adding  236177  to  /  resulting in  2490476
# Adding  228388  to  hqlmzshr  resulting in  228388
# Adding  228388  to  bjnvmpc  resulting in  646450
# Adding  228388  to  nmsvc  resulting in  1022998
# Adding  228388  to  cwdpn  resulting in  2718864
# Adding  228388  to  /  resulting in  2718864
# Adding  170034  to  smqzqrm  resulting in  170034
# Adding  170034  to  bjnvmpc  resulting in  816484
# Adding  170034  to  nmsvc  resulting in  1193032
# Adding  170034  to  cwdpn  resulting in  2888898
# Adding  170034  to  /  resulting in  2888898
# Adding  204754  to  bjnvmpc  resulting in  204754
# Adding  204754  to  jstfcllw  resulting in  204754
# Adding  204754  to  nmsvc  resulting in  1397786
# Adding  204754  to  cwdpn  resulting in  3093652
# Adding  204754  to  /  resulting in  3093652
# Adding  48598  to  bjnvmpc  resulting in  253352
# Adding  48598  to  jstfcllw  resulting in  253352
# Adding  48598  to  nmsvc  resulting in  1446384
# Adding  48598  to  cwdpn  resulting in  3142250
# Adding  48598  to  /  resulting in  3142250
# Adding  211685  to  bjnvmpc  resulting in  465037
# Adding  211685  to  jstfcllw  resulting in  465037
# Adding  211685  to  nmsvc  resulting in  1658069
# Adding  211685  to  cwdpn  resulting in  3353935
# Adding  211685  to  /  resulting in  3353935
# Adding  169343  to  fmjlrc  resulting in  169343
# Adding  169343  to  bjnvmpc  resulting in  634380
# Adding  169343  to  jstfcllw  resulting in  634380
# Adding  169343  to  nmsvc  resulting in  1827412
# Adding  169343  to  cwdpn  resulting in  3523278
# Adding  169343  to  /  resulting in  3523278
# Adding  179486  to  jtqgbwhb  resulting in  179486
# Adding  179486  to  nmsvc  resulting in  2006898
# Adding  179486  to  cwdpn  resulting in  3702764
# Adding  179486  to  /  resulting in  3702764
# Adding  76133  to  bjnvmpc  resulting in  76133
# Adding  76133  to  jtqgbwhb  resulting in  255619
# Adding  76133  to  nmsvc  resulting in  2083031
# Adding  76133  to  cwdpn  resulting in  3778897
# Adding  76133  to  /  resulting in  3778897
# Adding  266667  to  bjnvmpc  resulting in  342800
# Adding  266667  to  jtqgbwhb  resulting in  522286
# Adding  266667  to  nmsvc  resulting in  2349698
# Adding  266667  to  cwdpn  resulting in  4045564
# Adding  266667  to  /  resulting in  4045564
# Adding  242869  to  bjnvmpc  resulting in  585669
# Adding  242869  to  jtqgbwhb  resulting in  765155
# Adding  242869  to  nmsvc  resulting in  2592567
# Adding  242869  to  cwdpn  resulting in  4288433
# Adding  242869  to  /  resulting in  4288433
# Adding  253571  to  dbglngc  resulting in  253571
# Adding  253571  to  bjnvmpc  resulting in  839240
# Adding  253571  to  jtqgbwhb  resulting in  1018726
# Adding  253571  to  nmsvc  resulting in  2846138
# Adding  253571  to  cwdpn  resulting in  4542004
# Adding  253571  to  /  resulting in  4542004
# Adding  36586  to  hbfbvdr  resulting in  36586
# Adding  36586  to  dbglngc  resulting in  290157
# Adding  36586  to  bjnvmpc  resulting in  875826
# Adding  36586  to  jtqgbwhb  resulting in  1055312
# Adding  36586  to  nmsvc  resulting in  2882724
# Adding  36586  to  cwdpn  resulting in  4578590
# Adding  36586  to  /  resulting in  4578590
# Adding  78854  to  tlsd  resulting in  78854
# Adding  78854  to  dbglngc  resulting in  369011
# Adding  78854  to  bjnvmpc  resulting in  954680
# Adding  78854  to  jtqgbwhb  resulting in  1134166
# Adding  78854  to  nmsvc  resulting in  2961578
# Adding  78854  to  cwdpn  resulting in  4657444
# Adding  78854  to  /  resulting in  4657444
# Adding  102680  to  rdb  resulting in  102680
# Adding  102680  to  bjnvmpc  resulting in  1057360
# Adding  102680  to  jtqgbwhb  resulting in  1236846
# Adding  102680  to  nmsvc  resulting in  3064258
# Adding  102680  to  cwdpn  resulting in  4760124
# Adding  102680  to  /  resulting in  4760124
# Adding  227450  to  ddjpm  resulting in  227450
# Adding  227450  to  jtqgbwhb  resulting in  1464296
# Adding  227450  to  nmsvc  resulting in  3291708
# Adding  227450  to  cwdpn  resulting in  4987574
# Adding  227450  to  /  resulting in  4987574
# Adding  71376  to  ddjpm  resulting in  298826
# Adding  71376  to  jtqgbwhb  resulting in  1535672
# Adding  71376  to  nmsvc  resulting in  3363084
# Adding  71376  to  cwdpn  resulting in  5058950
# Adding  71376  to  /  resulting in  5058950
# Adding  86244  to  ddjpm  resulting in  385070
# Adding  86244  to  jtqgbwhb  resulting in  1621916
# Adding  86244  to  nmsvc  resulting in  3449328
# Adding  86244  to  cwdpn  resulting in  5145194
# Adding  86244  to  /  resulting in  5145194
# Adding  65644  to  fmtpwm  resulting in  65644
# Adding  65644  to  jtqgbwhb  resulting in  1687560
# Adding  65644  to  nmsvc  resulting in  3514972
# Adding  65644  to  cwdpn  resulting in  5210838
# Adding  65644  to  /  resulting in  5210838
# Adding  92435  to  fmtpwm  resulting in  158079
# Adding  92435  to  jtqgbwhb  resulting in  1779995
# Adding  92435  to  nmsvc  resulting in  3607407
# Adding  92435  to  cwdpn  resulting in  5303273
# Adding  92435  to  /  resulting in  5303273
# Adding  104193  to  ggpctlh  resulting in  104193
# Adding  104193  to  fmtpwm  resulting in  262272
# Adding  104193  to  jtqgbwhb  resulting in  1884188
# Adding  104193  to  nmsvc  resulting in  3711600
# Adding  104193  to  cwdpn  resulting in  5407466
# Adding  104193  to  /  resulting in  5407466
# Adding  28086  to  rdmgrtzl  resulting in  28086
# Adding  28086  to  ggpctlh  resulting in  132279
# Adding  28086  to  fmtpwm  resulting in  290358
# Adding  28086  to  jtqgbwhb  resulting in  1912274
# Adding  28086  to  nmsvc  resulting in  3739686
# Adding  28086  to  cwdpn  resulting in  5435552
# Adding  28086  to  /  resulting in  5435552
# Adding  165962  to  jstfcllw  resulting in  165962
# Adding  165962  to  ltqjb  resulting in  165962
# Adding  165962  to  nmsvc  resulting in  3905648
# Adding  165962  to  cwdpn  resulting in  5601514
# Adding  165962  to  /  resulting in  5601514
# Adding  26615  to  lqrf  resulting in  26615
# Adding  26615  to  swvlpql  resulting in  26615
# Adding  26615  to  vjrdcjbr  resulting in  26615
# Adding  26615  to  qjgbt  resulting in  26615
# Adding  26615  to  ltqjb  resulting in  192577
# Adding  26615  to  nmsvc  resulting in  3932263
# Adding  26615  to  cwdpn  resulting in  5628129
# Adding  26615  to  /  resulting in  5628129
# Adding  23820  to  nmsvc  resulting in  23820
# Adding  23820  to  swvlpql  resulting in  50435
# Adding  23820  to  vjrdcjbr  resulting in  50435
# Adding  23820  to  qjgbt  resulting in  50435
# Adding  23820  to  ltqjb  resulting in  216397
# Adding  23820  to  nmsvc  resulting in  3956083
# Adding  23820  to  cwdpn  resulting in  5651949
# Adding  23820  to  /  resulting in  5651949
# Adding  77703  to  nmsvc  resulting in  101523
# Adding  77703  to  swvlpql  resulting in  128138
# Adding  77703  to  vjrdcjbr  resulting in  128138
# Adding  77703  to  qjgbt  resulting in  128138
# Adding  77703  to  ltqjb  resulting in  294100
# Adding  77703  to  nmsvc  resulting in  4033786
# Adding  77703  to  cwdpn  resulting in  5729652
# Adding  77703  to  /  resulting in  5729652
# Adding  220326  to  nmsvc  resulting in  321849
# Adding  220326  to  swvlpql  resulting in  348464
# Adding  220326  to  vjrdcjbr  resulting in  348464
# Adding  220326  to  qjgbt  resulting in  348464
# Adding  220326  to  ltqjb  resulting in  514426
# Adding  220326  to  nmsvc  resulting in  4254112
# Adding  220326  to  cwdpn  resulting in  5949978
# Adding  220326  to  /  resulting in  5949978
# Adding  109078  to  wnvtfmfw  resulting in  109078
# Adding  109078  to  swvlpql  resulting in  457542
# Adding  109078  to  vjrdcjbr  resulting in  457542
# Adding  109078  to  qjgbt  resulting in  457542
# Adding  109078  to  ltqjb  resulting in  623504
# Adding  109078  to  nmsvc  resulting in  4363190
# Adding  109078  to  cwdpn  resulting in  6059056
# Adding  109078  to  /  resulting in  6059056
# Adding  285836  to  nmsvc  resulting in  285836
# Adding  285836  to  wmm  resulting in  285836
# Adding  285836  to  vjrdcjbr  resulting in  743378
# Adding  285836  to  qjgbt  resulting in  743378
# Adding  285836  to  ltqjb  resulting in  909340
# Adding  285836  to  nmsvc  resulting in  4649026
# Adding  285836  to  cwdpn  resulting in  6344892
# Adding  285836  to  /  resulting in  6344892
# Adding  226698  to  rstzf  resulting in  226698
# Adding  226698  to  ltqjb  resulting in  1136038
# Adding  226698  to  nmsvc  resulting in  4875724
# Adding  226698  to  cwdpn  resulting in  6571590
# Adding  226698  to  /  resulting in  6571590
# Adding  234472  to  rstzf  resulting in  461170
# Adding  234472  to  ltqjb  resulting in  1370510
# Adding  234472  to  nmsvc  resulting in  5110196
# Adding  234472  to  cwdpn  resulting in  6806062
# Adding  234472  to  /  resulting in  6806062
# Adding  118290  to  bjnvmpc  resulting in  118290
# Adding  118290  to  rstzf  resulting in  579460
# Adding  118290  to  ltqjb  resulting in  1488800
# Adding  118290  to  nmsvc  resulting in  5228486
# Adding  118290  to  cwdpn  resulting in  6924352
# Adding  118290  to  /  resulting in  6924352
# Adding  230555  to  mtctn  resulting in  230555
# Adding  230555  to  bjnvmpc  resulting in  348845
# Adding  230555  to  rstzf  resulting in  810015
# Adding  230555  to  ltqjb  resulting in  1719355
# Adding  230555  to  nmsvc  resulting in  5459041
# Adding  230555  to  cwdpn  resulting in  7154907
# Adding  230555  to  /  resulting in  7154907
# Adding  227496  to  nfb  resulting in  227496
# Adding  227496  to  mtctn  resulting in  458051
# Adding  227496  to  bjnvmpc  resulting in  576341
# Adding  227496  to  rstzf  resulting in  1037511
# Adding  227496  to  ltqjb  resulting in  1946851
# Adding  227496  to  nmsvc  resulting in  5686537
# Adding  227496  to  cwdpn  resulting in  7382403
# Adding  227496  to  /  resulting in  7382403
# Adding  154342  to  nfb  resulting in  381838
# Adding  154342  to  mtctn  resulting in  612393
# Adding  154342  to  bjnvmpc  resulting in  730683
# Adding  154342  to  rstzf  resulting in  1191853
# Adding  154342  to  ltqjb  resulting in  2101193
# Adding  154342  to  nmsvc  resulting in  5840879
# Adding  154342  to  cwdpn  resulting in  7536745
# Adding  154342  to  /  resulting in  7536745
# Adding  19020  to  bqjczmcr  resulting in  19020
# Adding  19020  to  nfb  resulting in  400858
# Adding  19020  to  mtctn  resulting in  631413
# Adding  19020  to  bjnvmpc  resulting in  749703
# Adding  19020  to  rstzf  resulting in  1210873
# Adding  19020  to  ltqjb  resulting in  2120213
# Adding  19020  to  nmsvc  resulting in  5859899
# Adding  19020  to  cwdpn  resulting in  7555765
# Adding  19020  to  /  resulting in  7555765
# Adding  255839  to  brhvhl  resulting in  255839
# Adding  255839  to  nfb  resulting in  656697
# Adding  255839  to  mtctn  resulting in  887252
# Adding  255839  to  bjnvmpc  resulting in  1005542
# Adding  255839  to  rstzf  resulting in  1466712
# Adding  255839  to  ltqjb  resulting in  2376052
# Adding  255839  to  nmsvc  resulting in  6115738
# Adding  255839  to  cwdpn  resulting in  7811604
# Adding  255839  to  /  resulting in  7811604
# Adding  155078  to  pfqv  resulting in  155078
# Adding  155078  to  mtctn  resulting in  1042330
# Adding  155078  to  bjnvmpc  resulting in  1160620
# Adding  155078  to  rstzf  resulting in  1621790
# Adding  155078  to  ltqjb  resulting in  2531130
# Adding  155078  to  nmsvc  resulting in  6270816
# Adding  155078  to  cwdpn  resulting in  7966682
# Adding  155078  to  /  resulting in  7966682
# Adding  180441  to  rjcpn  resulting in  180441
# Adding  180441  to  bjnvmpc  resulting in  1341061
# Adding  180441  to  rstzf  resulting in  1802231
# Adding  180441  to  ltqjb  resulting in  2711571
# Adding  180441  to  nmsvc  resulting in  6451257
# Adding  180441  to  cwdpn  resulting in  8147123
# Adding  180441  to  /  resulting in  8147123
# Adding  139942  to  rjcpn  resulting in  320383
# Adding  139942  to  bjnvmpc  resulting in  1481003
# Adding  139942  to  rstzf  resulting in  1942173
# Adding  139942  to  ltqjb  resulting in  2851513
# Adding  139942  to  nmsvc  resulting in  6591199
# Adding  139942  to  cwdpn  resulting in  8287065
# Adding  139942  to  /  resulting in  8287065
# Adding  237442  to  rjcpn  resulting in  557825
# Adding  237442  to  bjnvmpc  resulting in  1718445
# Adding  237442  to  rstzf  resulting in  2179615
# Adding  237442  to  ltqjb  resulting in  3088955
# Adding  237442  to  nmsvc  resulting in  6828641
# Adding  237442  to  cwdpn  resulting in  8524507
# Adding  237442  to  /  resulting in  8524507
# Adding  192628  to  rjcpn  resulting in  750453
# Adding  192628  to  bjnvmpc  resulting in  1911073
# Adding  192628  to  rstzf  resulting in  2372243
# Adding  192628  to  ltqjb  resulting in  3281583
# Adding  192628  to  nmsvc  resulting in  7021269
# Adding  192628  to  cwdpn  resulting in  8717135
# Adding  192628  to  /  resulting in  8717135
# Adding  188844  to  drjzphm  resulting in  188844
# Adding  188844  to  ggjrm  resulting in  188844
# Adding  188844  to  rjcpn  resulting in  939297
# Adding  188844  to  bjnvmpc  resulting in  2099917
# Adding  188844  to  rstzf  resulting in  2561087
# Adding  188844  to  ltqjb  resulting in  3470427
# Adding  188844  to  nmsvc  resulting in  7210113
# Adding  188844  to  cwdpn  resulting in  8905979
# Adding  188844  to  /  resulting in  8905979
# Adding  10806  to  llpmvt  resulting in  10806
# Adding  10806  to  rjcpn  resulting in  950103
# Adding  10806  to  bjnvmpc  resulting in  2110723
# Adding  10806  to  rstzf  resulting in  2571893
# Adding  10806  to  ltqjb  resulting in  3481233
# Adding  10806  to  nmsvc  resulting in  7220919
# Adding  10806  to  cwdpn  resulting in  8916785
# Adding  10806  to  /  resulting in  8916785
# Adding  31293  to  llpmvt  resulting in  42099
# Adding  31293  to  rjcpn  resulting in  981396
# Adding  31293  to  bjnvmpc  resulting in  2142016
# Adding  31293  to  rstzf  resulting in  2603186
# Adding  31293  to  ltqjb  resulting in  3512526
# Adding  31293  to  nmsvc  resulting in  7252212
# Adding  31293  to  cwdpn  resulting in  8948078
# Adding  31293  to  /  resulting in  8948078
# Adding  78642  to  bhdpfpb  resulting in  78642
# Adding  78642  to  llpmvt  resulting in  120741
# Adding  78642  to  rjcpn  resulting in  1060038
# Adding  78642  to  bjnvmpc  resulting in  2220658
# Adding  78642  to  rstzf  resulting in  2681828
# Adding  78642  to  ltqjb  resulting in  3591168
# Adding  78642  to  nmsvc  resulting in  7330854
# Adding  78642  to  cwdpn  resulting in  9026720
# Adding  78642  to  /  resulting in  9026720
# Adding  234658  to  jstfcllw  resulting in  234658
# Adding  234658  to  llpmvt  resulting in  355399
# Adding  234658  to  rjcpn  resulting in  1294696
# Adding  234658  to  bjnvmpc  resulting in  2455316
# Adding  234658  to  rstzf  resulting in  2916486
# Adding  234658  to  ltqjb  resulting in  3825826
# Adding  234658  to  nmsvc  resulting in  7565512
# Adding  234658  to  cwdpn  resulting in  9261378
# Adding  234658  to  /  resulting in  9261378
# Adding  194879  to  pvz  resulting in  194879
# Adding  194879  to  llpmvt  resulting in  550278
# Adding  194879  to  rjcpn  resulting in  1489575
# Adding  194879  to  bjnvmpc  resulting in  2650195
# Adding  194879  to  rstzf  resulting in  3111365
# Adding  194879  to  ltqjb  resulting in  4020705
# Adding  194879  to  nmsvc  resulting in  7760391
# Adding  194879  to  cwdpn  resulting in  9456257
# Adding  194879  to  /  resulting in  9456257
# Adding  225789  to  qntnwf  resulting in  225789
# Adding  225789  to  llpmvt  resulting in  776067
# Adding  225789  to  rjcpn  resulting in  1715364
# Adding  225789  to  bjnvmpc  resulting in  2875984
# Adding  225789  to  rstzf  resulting in  3337154
# Adding  225789  to  ltqjb  resulting in  4246494
# Adding  225789  to  nmsvc  resulting in  7986180
# Adding  225789  to  cwdpn  resulting in  9682046
# Adding  225789  to  /  resulting in  9682046
# Adding  136331  to  tbrccw  resulting in  136331
# Adding  136331  to  bjnvmpc  resulting in  3012315
# Adding  136331  to  rstzf  resulting in  3473485
# Adding  136331  to  ltqjb  resulting in  4382825
# Adding  136331  to  nmsvc  resulting in  8122511
# Adding  136331  to  cwdpn  resulting in  9818377
# Adding  136331  to  /  resulting in  9818377
# Adding  130573  to  tbrccw  resulting in  266904
# Adding  130573  to  bjnvmpc  resulting in  3142888
# Adding  130573  to  rstzf  resulting in  3604058
# Adding  130573  to  ltqjb  resulting in  4513398
# Adding  130573  to  nmsvc  resulting in  8253084
# Adding  130573  to  cwdpn  resulting in  9948950
# Adding  130573  to  /  resulting in  9948950
# Adding  271647  to  bjnvmpc  resulting in  271647
# Adding  271647  to  llpmvt  resulting in  271647
# Adding  271647  to  tbrccw  resulting in  538551
# Adding  271647  to  bjnvmpc  resulting in  3414535
# Adding  271647  to  rstzf  resulting in  3875705
# Adding  271647  to  ltqjb  resulting in  4785045
# Adding  271647  to  nmsvc  resulting in  8524731
# Adding  271647  to  cwdpn  resulting in  10220597
# Adding  271647  to  /  resulting in  10220597
# Adding  185622  to  nmsvc  resulting in  185622
# Adding  185622  to  tbrccw  resulting in  724173
# Adding  185622  to  bjnvmpc  resulting in  3600157
# Adding  185622  to  rstzf  resulting in  4061327
# Adding  185622  to  ltqjb  resulting in  4970667
# Adding  185622  to  nmsvc  resulting in  8710353
# Adding  185622  to  cwdpn  resulting in  10406219
# Adding  185622  to  /  resulting in  10406219
# Adding  102596  to  nmsvc  resulting in  288218
# Adding  102596  to  tbrccw  resulting in  826769
# Adding  102596  to  bjnvmpc  resulting in  3702753
# Adding  102596  to  rstzf  resulting in  4163923
# Adding  102596  to  ltqjb  resulting in  5073263
# Adding  102596  to  nmsvc  resulting in  8812949
# Adding  102596  to  cwdpn  resulting in  10508815
# Adding  102596  to  /  resulting in  10508815
# Adding  240  to  nmsvc  resulting in  288458
# Adding  240  to  tbrccw  resulting in  827009
# Adding  240  to  bjnvmpc  resulting in  3702993
# Adding  240  to  rstzf  resulting in  4164163
# Adding  240  to  ltqjb  resulting in  5073503
# Adding  240  to  nmsvc  resulting in  8813189
# Adding  240  to  cwdpn  resulting in  10509055
# Adding  240  to  /  resulting in  10509055
# Adding  157313  to  nmsvc  resulting in  445771
# Adding  157313  to  tbrccw  resulting in  984322
# Adding  157313  to  bjnvmpc  resulting in  3860306
# Adding  157313  to  rstzf  resulting in  4321476
# Adding  157313  to  ltqjb  resulting in  5230816
# Adding  157313  to  nmsvc  resulting in  8970502
# Adding  157313  to  cwdpn  resulting in  10666368
# Adding  157313  to  /  resulting in  10666368
# Adding  270091  to  scpwzh  resulting in  270091
# Adding  270091  to  tbrccw  resulting in  1254413
# Adding  270091  to  bjnvmpc  resulting in  4130397
# Adding  270091  to  rstzf  resulting in  4591567
# Adding  270091  to  ltqjb  resulting in  5500907
# Adding  270091  to  nmsvc  resulting in  9240593
# Adding  270091  to  cwdpn  resulting in  10936459
# Adding  270091  to  /  resulting in  10936459
# Adding  109316  to  fwmvpthq  resulting in  109316
# Adding  109316  to  rstzf  resulting in  4700883
# Adding  109316  to  ltqjb  resulting in  5610223
# Adding  109316  to  nmsvc  resulting in  9349909
# Adding  109316  to  cwdpn  resulting in  11045775
# Adding  109316  to  /  resulting in  11045775
# Adding  90010  to  fwmvpthq  resulting in  199326
# Adding  90010  to  rstzf  resulting in  4790893
# Adding  90010  to  ltqjb  resulting in  5700233
# Adding  90010  to  nmsvc  resulting in  9439919
# Adding  90010  to  cwdpn  resulting in  11135785
# Adding  90010  to  /  resulting in  11135785
# Adding  193177  to  fwmvpthq  resulting in  392503
# Adding  193177  to  rstzf  resulting in  4984070
# Adding  193177  to  ltqjb  resulting in  5893410
# Adding  193177  to  nmsvc  resulting in  9633096
# Adding  193177  to  cwdpn  resulting in  11328962
# Adding  193177  to  /  resulting in  11328962
# Adding  283398  to  fwmvpthq  resulting in  675901
# Adding  283398  to  rstzf  resulting in  5267468
# Adding  283398  to  ltqjb  resulting in  6176808
# Adding  283398  to  nmsvc  resulting in  9916494
# Adding  283398  to  cwdpn  resulting in  11612360
# Adding  283398  to  /  resulting in  11612360
# Adding  59723  to  llpmvt  resulting in  59723
# Adding  59723  to  fwmvpthq  resulting in  735624
# Adding  59723  to  rstzf  resulting in  5327191
# Adding  59723  to  ltqjb  resulting in  6236531
# Adding  59723  to  nmsvc  resulting in  9976217
# Adding  59723  to  cwdpn  resulting in  11672083
# Adding  59723  to  /  resulting in  11672083
# Adding  74258  to  gjtj  resulting in  74258
# Adding  74258  to  bgvjb  resulting in  74258
# Adding  74258  to  llpmvt  resulting in  133981
# Adding  74258  to  fwmvpthq  resulting in  809882
# Adding  74258  to  rstzf  resulting in  5401449
# Adding  74258  to  ltqjb  resulting in  6310789
# Adding  74258  to  nmsvc  resulting in  10050475
# Adding  74258  to  cwdpn  resulting in  11746341
# Adding  74258  to  /  resulting in  11746341
# Adding  227910  to  nmsvc  resulting in  227910
# Adding  227910  to  bgvjb  resulting in  302168
# Adding  227910  to  llpmvt  resulting in  361891
# Adding  227910  to  fwmvpthq  resulting in  1037792
# Adding  227910  to  rstzf  resulting in  5629359
# Adding  227910  to  ltqjb  resulting in  6538699
# Adding  227910  to  nmsvc  resulting in  10278385
# Adding  227910  to  cwdpn  resulting in  11974251
# Adding  227910  to  /  resulting in  11974251
# Adding  286951  to  nmsvc  resulting in  514861
# Adding  286951  to  bgvjb  resulting in  589119
# Adding  286951  to  llpmvt  resulting in  648842
# Adding  286951  to  fwmvpthq  resulting in  1324743
# Adding  286951  to  rstzf  resulting in  5916310
# Adding  286951  to  ltqjb  resulting in  6825650
# Adding  286951  to  nmsvc  resulting in  10565336
# Adding  286951  to  cwdpn  resulting in  12261202
# Adding  286951  to  /  resulting in  12261202
# Adding  191813  to  wrwsn  resulting in  191813
# Adding  191813  to  bgvjb  resulting in  780932
# Adding  191813  to  llpmvt  resulting in  840655
# Adding  191813  to  fwmvpthq  resulting in  1516556
# Adding  191813  to  rstzf  resulting in  6108123
# Adding  191813  to  ltqjb  resulting in  7017463
# Adding  191813  to  nmsvc  resulting in  10757149
# Adding  191813  to  cwdpn  resulting in  12453015
# Adding  191813  to  /  resulting in  12453015
# Adding  7096  to  nmsvc  resulting in  7096
# Adding  7096  to  fwmvpthq  resulting in  1523652
# Adding  7096  to  rstzf  resulting in  6115219
# Adding  7096  to  ltqjb  resulting in  7024559
# Adding  7096  to  nmsvc  resulting in  10764245
# Adding  7096  to  cwdpn  resulting in  12460111
# Adding  7096  to  /  resulting in  12460111
# Adding  102123  to  nmsvc  resulting in  109219
# Adding  102123  to  fwmvpthq  resulting in  1625775
# Adding  102123  to  rstzf  resulting in  6217342
# Adding  102123  to  ltqjb  resulting in  7126682
# Adding  102123  to  nmsvc  resulting in  10866368
# Adding  102123  to  cwdpn  resulting in  12562234
# Adding  102123  to  /  resulting in  12562234
# Adding  160466  to  nmsvc  resulting in  269685
# Adding  160466  to  fwmvpthq  resulting in  1786241
# Adding  160466  to  rstzf  resulting in  6377808
# Adding  160466  to  ltqjb  resulting in  7287148
# Adding  160466  to  nmsvc  resulting in  11026834
# Adding  160466  to  cwdpn  resulting in  12722700
# Adding  160466  to  /  resulting in  12722700
# Adding  266774  to  ntmfpmr  resulting in  266774
# Adding  266774  to  fwmvpthq  resulting in  2053015
# Adding  266774  to  rstzf  resulting in  6644582
# Adding  266774  to  ltqjb  resulting in  7553922
# Adding  266774  to  nmsvc  resulting in  11293608
# Adding  266774  to  cwdpn  resulting in  12989474
# Adding  266774  to  /  resulting in  12989474
# Adding  181175  to  pnrbvd  resulting in  181175
# Adding  181175  to  fwmvpthq  resulting in  2234190
# Adding  181175  to  rstzf  resulting in  6825757
# Adding  181175  to  ltqjb  resulting in  7735097
# Adding  181175  to  nmsvc  resulting in  11474783
# Adding  181175  to  cwdpn  resulting in  13170649
# Adding  181175  to  /  resulting in  13170649
# Adding  164233  to  pnrbvd  resulting in  345408
# Adding  164233  to  fwmvpthq  resulting in  2398423
# Adding  164233  to  rstzf  resulting in  6989990
# Adding  164233  to  ltqjb  resulting in  7899330
# Adding  164233  to  nmsvc  resulting in  11639016
# Adding  164233  to  cwdpn  resulting in  13334882
# Adding  164233  to  /  resulting in  13334882
# Adding  125821  to  bbpq  resulting in  125821
# Adding  125821  to  pnrbvd  resulting in  471229
# Adding  125821  to  fwmvpthq  resulting in  2524244
# Adding  125821  to  rstzf  resulting in  7115811
# Adding  125821  to  ltqjb  resulting in  8025151
# Adding  125821  to  nmsvc  resulting in  11764837
# Adding  125821  to  cwdpn  resulting in  13460703
# Adding  125821  to  /  resulting in  13460703
# Adding  40100  to  nmsvc  resulting in  40100
# Adding  40100  to  pnrbvd  resulting in  511329
# Adding  40100  to  fwmvpthq  resulting in  2564344
# Adding  40100  to  rstzf  resulting in  7155911
# Adding  40100  to  ltqjb  resulting in  8065251
# Adding  40100  to  nmsvc  resulting in  11804937
# Adding  40100  to  cwdpn  resulting in  13500803
# Adding  40100  to  /  resulting in  13500803
# Adding  112507  to  zpjqjtsl  resulting in  112507
# Adding  112507  to  shgtbbfw  resulting in  112507
# Adding  112507  to  fwmvpthq  resulting in  2676851
# Adding  112507  to  rstzf  resulting in  7268418
# Adding  112507  to  ltqjb  resulting in  8177758
# Adding  112507  to  nmsvc  resulting in  11917444
# Adding  112507  to  cwdpn  resulting in  13613310
# Adding  112507  to  /  resulting in  13613310
# Adding  199105  to  llpmvt  resulting in  199105
# Adding  199105  to  rstzf  resulting in  7467523
# Adding  199105  to  ltqjb  resulting in  8376863
# Adding  199105  to  nmsvc  resulting in  12116549
# Adding  199105  to  cwdpn  resulting in  13812415
# Adding  199105  to  /  resulting in  13812415
# Adding  133701  to  llpmvt  resulting in  332806
# Adding  133701  to  rstzf  resulting in  7601224
# Adding  133701  to  ltqjb  resulting in  8510564
# Adding  133701  to  nmsvc  resulting in  12250250
# Adding  133701  to  cwdpn  resulting in  13946116
# Adding  133701  to  /  resulting in  13946116
# Adding  102349  to  llpmvt  resulting in  435155
# Adding  102349  to  rstzf  resulting in  7703573
# Adding  102349  to  ltqjb  resulting in  8612913
# Adding  102349  to  nmsvc  resulting in  12352599
# Adding  102349  to  cwdpn  resulting in  14048465
# Adding  102349  to  /  resulting in  14048465
# Adding  89208  to  nmsvc  resulting in  89208
# Adding  89208  to  llpmvt  resulting in  524363
# Adding  89208  to  rstzf  resulting in  7792781
# Adding  89208  to  ltqjb  resulting in  8702121
# Adding  89208  to  nmsvc  resulting in  12441807
# Adding  89208  to  cwdpn  resulting in  14137673
# Adding  89208  to  /  resulting in  14137673
# Adding  176669  to  nmsvc  resulting in  265877
# Adding  176669  to  llpmvt  resulting in  701032
# Adding  176669  to  rstzf  resulting in  7969450
# Adding  176669  to  ltqjb  resulting in  8878790
# Adding  176669  to  nmsvc  resulting in  12618476
# Adding  176669  to  cwdpn  resulting in  14314342
# Adding  176669  to  /  resulting in  14314342
# Adding  178532  to  pnrbvd  resulting in  178532
# Adding  178532  to  llpmvt  resulting in  879564
# Adding  178532  to  rstzf  resulting in  8147982
# Adding  178532  to  ltqjb  resulting in  9057322
# Adding  178532  to  nmsvc  resulting in  12797008
# Adding  178532  to  cwdpn  resulting in  14492874
# Adding  178532  to  /  resulting in  14492874
# Adding  51572  to  hchfn  resulting in  51572
# Adding  51572  to  pnrbvd  resulting in  230104
# Adding  51572  to  llpmvt  resulting in  931136
# Adding  51572  to  rstzf  resulting in  8199554
# Adding  51572  to  ltqjb  resulting in  9108894
# Adding  51572  to  nmsvc  resulting in  12848580
# Adding  51572  to  cwdpn  resulting in  14544446
# Adding  51572  to  /  resulting in  14544446
# Adding  281362  to  hchfn  resulting in  332934
# Adding  281362  to  pnrbvd  resulting in  511466
# Adding  281362  to  llpmvt  resulting in  1212498
# Adding  281362  to  rstzf  resulting in  8480916
# Adding  281362  to  ltqjb  resulting in  9390256
# Adding  281362  to  nmsvc  resulting in  13129942
# Adding  281362  to  cwdpn  resulting in  14825808
# Adding  281362  to  /  resulting in  14825808
# Adding  63202  to  llpmvt  resulting in  63202
# Adding  63202  to  pnrbvd  resulting in  574668
# Adding  63202  to  llpmvt  resulting in  1275700
# Adding  63202  to  rstzf  resulting in  8544118
# Adding  63202  to  ltqjb  resulting in  9453458
# Adding  63202  to  nmsvc  resulting in  13193144
# Adding  63202  to  cwdpn  resulting in  14889010
# Adding  63202  to  /  resulting in  14889010
# Adding  255774  to  llpmvt  resulting in  318976
# Adding  255774  to  pnrbvd  resulting in  830442
# Adding  255774  to  llpmvt  resulting in  1531474
# Adding  255774  to  rstzf  resulting in  8799892
# Adding  255774  to  ltqjb  resulting in  9709232
# Adding  255774  to  nmsvc  resulting in  13448918
# Adding  255774  to  cwdpn  resulting in  15144784
# Adding  255774  to  /  resulting in  15144784
# Adding  60903  to  llpmvt  resulting in  379879
# Adding  60903  to  pnrbvd  resulting in  891345
# Adding  60903  to  llpmvt  resulting in  1592377
# Adding  60903  to  rstzf  resulting in  8860795
# Adding  60903  to  ltqjb  resulting in  9770135
# Adding  60903  to  nmsvc  resulting in  13509821
# Adding  60903  to  cwdpn  resulting in  15205687
# Adding  60903  to  /  resulting in  15205687
# Adding  274603  to  llpmvt  resulting in  654482
# Adding  274603  to  pnrbvd  resulting in  1165948
# Adding  274603  to  llpmvt  resulting in  1866980
# Adding  274603  to  rstzf  resulting in  9135398
# Adding  274603  to  ltqjb  resulting in  10044738
# Adding  274603  to  nmsvc  resulting in  13784424
# Adding  274603  to  cwdpn  resulting in  15480290
# Adding  274603  to  /  resulting in  15480290
# Adding  40626  to  gdfwttff  resulting in  40626
# Adding  40626  to  mpz  resulting in  40626
# Adding  40626  to  rstzf  resulting in  9176024
# Adding  40626  to  ltqjb  resulting in  10085364
# Adding  40626  to  nmsvc  resulting in  13825050
# Adding  40626  to  cwdpn  resulting in  15520916
# Adding  40626  to  /  resulting in  15520916
# Adding  69007  to  jstfcllw  resulting in  69007
# Adding  69007  to  njptwz  resulting in  69007
# Adding  69007  to  mpz  resulting in  109633
# Adding  69007  to  rstzf  resulting in  9245031
# Adding  69007  to  ltqjb  resulting in  10154371
# Adding  69007  to  nmsvc  resulting in  13894057
# Adding  69007  to  cwdpn  resulting in  15589923
# Adding  69007  to  /  resulting in  15589923
# Adding  153157  to  pnrbvd  resulting in  153157
# Adding  153157  to  mpz  resulting in  262790
# Adding  153157  to  rstzf  resulting in  9398188
# Adding  153157  to  ltqjb  resulting in  10307528
# Adding  153157  to  nmsvc  resulting in  14047214
# Adding  153157  to  cwdpn  resulting in  15743080
# Adding  153157  to  /  resulting in  15743080
# Adding  157128  to  zcvn  resulting in  157128
# Adding  157128  to  mpz  resulting in  419918
# Adding  157128  to  rstzf  resulting in  9555316
# Adding  157128  to  ltqjb  resulting in  10464656
# Adding  157128  to  nmsvc  resulting in  14204342
# Adding  157128  to  cwdpn  resulting in  15900208
# Adding  157128  to  /  resulting in  15900208
# Adding  234947  to  qpvnfl  resulting in  234947
# Adding  234947  to  rstzf  resulting in  9790263
# Adding  234947  to  ltqjb  resulting in  10699603
# Adding  234947  to  nmsvc  resulting in  14439289
# Adding  234947  to  cwdpn  resulting in  16135155
# Adding  234947  to  /  resulting in  16135155
# Adding  80105  to  rmrngqdg  resulting in  80105
# Adding  80105  to  rstzf  resulting in  9870368
# Adding  80105  to  ltqjb  resulting in  10779708
# Adding  80105  to  nmsvc  resulting in  14519394
# Adding  80105  to  cwdpn  resulting in  16215260
# Adding  80105  to  /  resulting in  16215260
# Adding  185789  to  rmrngqdg  resulting in  265894
# Adding  185789  to  rstzf  resulting in  10056157
# Adding  185789  to  ltqjb  resulting in  10965497
# Adding  185789  to  nmsvc  resulting in  14705183
# Adding  185789  to  cwdpn  resulting in  16401049
# Adding  185789  to  /  resulting in  16401049
# Adding  181438  to  bjnvmpc  resulting in  181438
# Adding  181438  to  rmrngqdg  resulting in  447332
# Adding  181438  to  rstzf  resulting in  10237595
# Adding  181438  to  ltqjb  resulting in  11146935
# Adding  181438  to  nmsvc  resulting in  14886621
# Adding  181438  to  cwdpn  resulting in  16582487
# Adding  181438  to  /  resulting in  16582487
# Adding  191048  to  wvg  resulting in  191048
# Adding  191048  to  rmrngqdg  resulting in  638380
# Adding  191048  to  rstzf  resulting in  10428643
# Adding  191048  to  ltqjb  resulting in  11337983
# Adding  191048  to  nmsvc  resulting in  15077669
# Adding  191048  to  cwdpn  resulting in  16773535
# Adding  191048  to  /  resulting in  16773535
# Adding  9887  to  hlwjtqzj  resulting in  9887
# Adding  9887  to  wvg  resulting in  200935
# Adding  9887  to  rmrngqdg  resulting in  648267
# Adding  9887  to  rstzf  resulting in  10438530
# Adding  9887  to  ltqjb  resulting in  11347870
# Adding  9887  to  nmsvc  resulting in  15087556
# Adding  9887  to  cwdpn  resulting in  16783422
# Adding  9887  to  /  resulting in  16783422
# Adding  271916  to  tmrn  resulting in  271916
# Adding  271916  to  nmsvc  resulting in  15359472
# Adding  271916  to  cwdpn  resulting in  17055338
# Adding  271916  to  /  resulting in  17055338
# Adding  9555  to  tmrn  resulting in  281471
# Adding  9555  to  nmsvc  resulting in  15369027
# Adding  9555  to  cwdpn  resulting in  17064893
# Adding  9555  to  /  resulting in  17064893
# Adding  198388  to  tmrn  resulting in  479859
# Adding  198388  to  nmsvc  resulting in  15567415
# Adding  198388  to  cwdpn  resulting in  17263281
# Adding  198388  to  /  resulting in  17263281
# Adding  246330  to  tmrn  resulting in  726189
# Adding  246330  to  nmsvc  resulting in  15813745
# Adding  246330  to  cwdpn  resulting in  17509611
# Adding  246330  to  /  resulting in  17509611
# Adding  204067  to  zmsbdc  resulting in  204067
# Adding  204067  to  zzmpts  resulting in  204067
# Adding  204067  to  tmrn  resulting in  930256
# Adding  204067  to  nmsvc  resulting in  16017812
# Adding  204067  to  cwdpn  resulting in  17713678
# Adding  204067  to  /  resulting in  17713678
# Adding  103462  to  vzvwphz  resulting in  103462
# Adding  103462  to  nmsvc  resulting in  16121274
# Adding  103462  to  cwdpn  resulting in  17817140
# Adding  103462  to  /  resulting in  17817140
# Adding  61744  to  bqvdvllf  resulting in  61744
# Adding  61744  to  nmsvc  resulting in  61744
# Adding  61744  to  vzvwphz  resulting in  165206
# Adding  61744  to  nmsvc  resulting in  16183018
# Adding  61744  to  cwdpn  resulting in  17878884
# Adding  61744  to  /  resulting in  17878884
# Adding  154294  to  bqvdvllf  resulting in  216038
# Adding  154294  to  nmsvc  resulting in  216038
# Adding  154294  to  vzvwphz  resulting in  319500
# Adding  154294  to  nmsvc  resulting in  16337312
# Adding  154294  to  cwdpn  resulting in  18033178
# Adding  154294  to  /  resulting in  18033178
# Adding  277273  to  ghdlvvfs  resulting in  277273
# Adding  277273  to  nmsvc  resulting in  493311
# Adding  277273  to  vzvwphz  resulting in  596773
# Adding  277273  to  nmsvc  resulting in  16614585
# Adding  277273  to  cwdpn  resulting in  18310451
# Adding  277273  to  /  resulting in  18310451
# Adding  124476  to  ntmmcjh  resulting in  124476
# Adding  124476  to  vzvwphz  resulting in  721249
# Adding  124476  to  nmsvc  resulting in  16739061
# Adding  124476  to  cwdpn  resulting in  18434927
# Adding  124476  to  /  resulting in  18434927
# Adding  110867  to  ntmmcjh  resulting in  235343
# Adding  110867  to  vzvwphz  resulting in  832116
# Adding  110867  to  nmsvc  resulting in  16849928
# Adding  110867  to  cwdpn  resulting in  18545794
# Adding  110867  to  /  resulting in  18545794
# Adding  12568  to  ntmmcjh  resulting in  247911
# Adding  12568  to  vzvwphz  resulting in  844684
# Adding  12568  to  nmsvc  resulting in  16862496
# Adding  12568  to  cwdpn  resulting in  18558362
# Adding  12568  to  /  resulting in  18558362
# Adding  19181  to  ntmmcjh  resulting in  267092
# Adding  19181  to  vzvwphz  resulting in  863865
# Adding  19181  to  nmsvc  resulting in  16881677
# Adding  19181  to  cwdpn  resulting in  18577543
# Adding  19181  to  /  resulting in  18577543
# Adding  57593  to  rvwjl  resulting in  57593
# Adding  57593  to  vzvwphz  resulting in  921458
# Adding  57593  to  nmsvc  resulting in  16939270
# Adding  57593  to  cwdpn  resulting in  18635136
# Adding  57593  to  /  resulting in  18635136
# Adding  221008  to  rvwjl  resulting in  278601
# Adding  221008  to  vzvwphz  resulting in  1142466
# Adding  221008  to  nmsvc  resulting in  17160278
# Adding  221008  to  cwdpn  resulting in  18856144
# Adding  221008  to  /  resulting in  18856144
# Adding  12478  to  rvwjl  resulting in  291079
# Adding  12478  to  vzvwphz  resulting in  1154944
# Adding  12478  to  nmsvc  resulting in  17172756
# Adding  12478  to  cwdpn  resulting in  18868622
# Adding  12478  to  /  resulting in  18868622
# Adding  149624  to  rvwjl  resulting in  440703
# Adding  149624  to  vzvwphz  resulting in  1304568
# Adding  149624  to  nmsvc  resulting in  17322380
# Adding  149624  to  cwdpn  resulting in  19018246
# Adding  149624  to  /  resulting in  19018246
# Adding  131800  to  jstfcllw  resulting in  131800
# Adding  131800  to  rvwjl  resulting in  572503
# Adding  131800  to  vzvwphz  resulting in  1436368
# Adding  131800  to  nmsvc  resulting in  17454180
# Adding  131800  to  cwdpn  resulting in  19150046
# Adding  131800  to  /  resulting in  19150046
# Adding  20154  to  jstfcllw  resulting in  151954
# Adding  20154  to  rvwjl  resulting in  592657
# Adding  20154  to  vzvwphz  resulting in  1456522
# Adding  20154  to  nmsvc  resulting in  17474334
# Adding  20154  to  cwdpn  resulting in  19170200
# Adding  20154  to  /  resulting in  19170200
# Adding  135946  to  rgbdq  resulting in  135946
# Adding  135946  to  cwdpn  resulting in  19306146
# Adding  135946  to  /  resulting in  19306146
# Adding  186972  to  rgbdq  resulting in  322918
# Adding  186972  to  cwdpn  resulting in  19493118
# Adding  186972  to  /  resulting in  19493118
# Adding  151369  to  rgbdq  resulting in  474287
# Adding  151369  to  cwdpn  resulting in  19644487
# Adding  151369  to  /  resulting in  19644487
# Adding  125605  to  rgbdq  resulting in  599892
# Adding  125605  to  cwdpn  resulting in  19770092
# Adding  125605  to  /  resulting in  19770092
# Adding  165348  to  rgbdq  resulting in  765240
# Adding  165348  to  cwdpn  resulting in  19935440
# Adding  165348  to  /  resulting in  19935440
# Adding  209144  to  drzllllv  resulting in  209144
# Adding  209144  to  /  resulting in  20144584
# Adding  237212  to  mzfzzgsv  resulting in  237212
# Adding  237212  to  drzllllv  resulting in  446356
# Adding  237212  to  /  resulting in  20381796
# Adding  10557  to  fqflwvh  resulting in  10557
# Adding  10557  to  /  resulting in  20392353
# Adding  11071  to  fqflwvh  resulting in  21628
# Adding  11071  to  /  resulting in  20403424
# Adding  209490  to  fqflwvh  resulting in  231118
# Adding  209490  to  /  resulting in  20612914
# Adding  99206  to  fqflwvh  resulting in  330324
# Adding  99206  to  /  resulting in  20712120
# Adding  139022  to  fqflwvh  resulting in  469346
# Adding  139022  to  /  resulting in  20851142
# Adding  223773  to  jzlgzd  resulting in  223773
# Adding  223773  to  fqflwvh  resulting in  693119
# Adding  223773  to  /  resulting in  21074915
# Adding  80522  to  jzwwgjh  resulting in  80522
# Adding  80522  to  fqflwvh  resulting in  773641
# Adding  80522  to  /  resulting in  21155437
# Adding  219887  to  nfh  resulting in  219887
# Adding  219887  to  fqflwvh  resulting in  993528
# Adding  219887  to  /  resulting in  21375324
# Adding  145633  to  nfh  resulting in  365520
# Adding  145633  to  fqflwvh  resulting in  1139161
# Adding  145633  to  /  resulting in  21520957
# Adding  93312  to  nfh  resulting in  458832
# Adding  93312  to  fqflwvh  resulting in  1232473
# Adding  93312  to  /  resulting in  21614269
# Adding  65642  to  nfh  resulting in  524474
# Adding  65642  to  fqflwvh  resulting in  1298115
# Adding  65642  to  /  resulting in  21679911
# Adding  269811  to  nfh  resulting in  794285
# Adding  269811  to  fqflwvh  resulting in  1567926
# Adding  269811  to  /  resulting in  21949722
# Adding  34834  to  bzrfbfp  resulting in  34834
# Adding  34834  to  bfj  resulting in  34834
# Adding  34834  to  nfh  resulting in  829119
# Adding  34834  to  fqflwvh  resulting in  1602760
# Adding  34834  to  /  resulting in  21984556
# Adding  68732  to  pnrbvd  resulting in  68732
# Adding  68732  to  bfj  resulting in  103566
# Adding  68732  to  nfh  resulting in  897851
# Adding  68732  to  fqflwvh  resulting in  1671492
# Adding  68732  to  /  resulting in  22053288
# Adding  91779  to  rbq  resulting in  91779
# Adding  91779  to  bfj  resulting in  195345
# Adding  91779  to  nfh  resulting in  989630
# Adding  91779  to  fqflwvh  resulting in  1763271
# Adding  91779  to  /  resulting in  22145067
# Adding  114048  to  bjnvmpc  resulting in  114048
# Adding  114048  to  nfh  resulting in  1103678
# Adding  114048  to  fqflwvh  resulting in  1877319
# Adding  114048  to  /  resulting in  22259115
# Adding  44465  to  nbfsjvzn  resulting in  44465
# Adding  44465  to  nfh  resulting in  1148143
# Adding  44465  to  fqflwvh  resulting in  1921784
# Adding  44465  to  /  resulting in  22303580
# Adding  157458  to  nbfsjvzn  resulting in  201923
# Adding  157458  to  nfh  resulting in  1305601
# Adding  157458  to  fqflwvh  resulting in  2079242
# Adding  157458  to  /  resulting in  22461038
# Adding  40294  to  pnrbvd  resulting in  40294
# Adding  40294  to  nfh  resulting in  1345895
# Adding  40294  to  fqflwvh  resulting in  2119536
# Adding  40294  to  /  resulting in  22501332
# Adding  119065  to  pnrbvd  resulting in  159359
# Adding  119065  to  nfh  resulting in  1464960
# Adding  119065  to  fqflwvh  resulting in  2238601
# Adding  119065  to  /  resulting in  22620397
# Adding  271425  to  pnrbvd  resulting in  430784
# Adding  271425  to  nfh  resulting in  1736385
# Adding  271425  to  fqflwvh  resulting in  2510026
# Adding  271425  to  /  resulting in  22891822
# Adding  231623  to  pnrbvd  resulting in  662407
# Adding  231623  to  nfh  resulting in  1968008
# Adding  231623  to  fqflwvh  resulting in  2741649
# Adding  231623  to  /  resulting in  23123445
# Adding  175155  to  qhn  resulting in  175155
# Adding  175155  to  nfh  resulting in  2143163
# Adding  175155  to  fqflwvh  resulting in  2916804
# Adding  175155  to  /  resulting in  23298600
# Adding  30969  to  qhn  resulting in  206124
# Adding  30969  to  nfh  resulting in  2174132
# Adding  30969  to  fqflwvh  resulting in  2947773
# Adding  30969  to  /  resulting in  23329569
# Adding  276798  to  qhn  resulting in  482922
# Adding  276798  to  nfh  resulting in  2450930
# Adding  276798  to  fqflwvh  resulting in  3224571
# Adding  276798  to  /  resulting in  23606367
# Adding  30980  to  fsgn  resulting in  30980
# Adding  30980  to  qhn  resulting in  513902
# Adding  30980  to  nfh  resulting in  2481910
# Adding  30980  to  fqflwvh  resulting in  3255551
# Adding  30980  to  /  resulting in  23637347
# Adding  116742  to  fsgn  resulting in  147722
# Adding  116742  to  qhn  resulting in  630644
# Adding  116742  to  nfh  resulting in  2598652
# Adding  116742  to  fqflwvh  resulting in  3372293
# Adding  116742  to  /  resulting in  23754089
# Adding  194210  to  fsgn  resulting in  341932
# Adding  194210  to  qhn  resulting in  824854
# Adding  194210  to  nfh  resulting in  2792862
# Adding  194210  to  fqflwvh  resulting in  3566503
# Adding  194210  to  /  resulting in  23948299
# Adding  105346  to  fsgn  resulting in  447278
# Adding  105346  to  qhn  resulting in  930200
# Adding  105346  to  nfh  resulting in  2898208
# Adding  105346  to  fqflwvh  resulting in  3671849
# Adding  105346  to  /  resulting in  24053645
# Adding  182505  to  fsgn  resulting in  629783
# Adding  182505  to  qhn  resulting in  1112705
# Adding  182505  to  nfh  resulting in  3080713
# Adding  182505  to  fqflwvh  resulting in  3854354
# Adding  182505  to  /  resulting in  24236150
# Adding  98971  to  btpqsr  resulting in  98971
# Adding  98971  to  fsgn  resulting in  728754
# Adding  98971  to  qhn  resulting in  1211676
# Adding  98971  to  nfh  resulting in  3179684
# Adding  98971  to  fqflwvh  resulting in  3953325
# Adding  98971  to  /  resulting in  24335121
# Adding  79166  to  btpqsr  resulting in  178137
# Adding  79166  to  fsgn  resulting in  807920
# Adding  79166  to  qhn  resulting in  1290842
# Adding  79166  to  nfh  resulting in  3258850
# Adding  79166  to  fqflwvh  resulting in  4032491
# Adding  79166  to  /  resulting in  24414287
# Adding  94138  to  btpqsr  resulting in  272275
# Adding  94138  to  fsgn  resulting in  902058
# Adding  94138  to  qhn  resulting in  1384980
# Adding  94138  to  nfh  resulting in  3352988
# Adding  94138  to  fqflwvh  resulting in  4126629
# Adding  94138  to  /  resulting in  24508425
# Adding  288381  to  btpqsr  resulting in  560656
# Adding  288381  to  fsgn  resulting in  1190439
# Adding  288381  to  qhn  resulting in  1673361
# Adding  288381  to  nfh  resulting in  3641369
# Adding  288381  to  fqflwvh  resulting in  4415010
# Adding  288381  to  /  resulting in  24796806
# Adding  189962  to  jcj  resulting in  189962
# Adding  189962  to  btpqsr  resulting in  750618
# Adding  189962  to  fsgn  resulting in  1380401
# ...
# Adding  13607  to  fnnjdr  resulting in  217927
# Adding  13607  to  jstfcllw  resulting in  217927
# Adding  13607  to  /  resulting in  29439136
# Adding  123612  to  rhzsnr  resulting in  137219
# Adding  123612  to  bjnvmpc  resulting in  341539
# Adding  123612  to  fnnjdr  resulting in  341539
# Adding  123612  to  jstfcllw  resulting in  341539
# Adding  123612  to  /  resulting in  29562748
# Adding  155260  to  rhzsnr  resulting in  292479
# Adding  155260  to  bjnvmpc  resulting in  496799
# Adding  155260  to  fnnjdr  resulting in  496799
# Adding  155260  to  jstfcllw  resulting in  496799
# Adding  155260  to  /  resulting in  29718008
# Adding  228650  to  rhzsnr  resulting in  521129
# Adding  228650  to  bjnvmpc  resulting in  725449
# Adding  228650  to  fnnjdr  resulting in  725449
# Adding  228650  to  jstfcllw  resulting in  725449
# Adding  228650  to  /  resulting in  29946658
# Adding  229752  to  rhzsnr  resulting in  750881
# Adding  229752  to  bjnvmpc  resulting in  955201
# Adding  229752  to  fnnjdr  resulting in  955201
# Adding  229752  to  jstfcllw  resulting in  955201
# Adding  229752  to  /  resulting in  30176410
# Adding  101671  to  jstfcllw  resulting in  101671
# Adding  101671  to  rhzsnr  resulting in  852552
# Adding  101671  to  bjnvmpc  resulting in  1056872
# Adding  101671  to  fnnjdr  resulting in  1056872
# Adding  101671  to  jstfcllw  resulting in  1056872
# Adding  101671  to  /  resulting in  30278081
# Adding  94962  to  qtsrhfv  resulting in  94962
# Adding  94962  to  fcbs  resulting in  94962
# Adding  94962  to  jstfcllw  resulting in  196633
# Adding  94962  to  rhzsnr  resulting in  947514
# Adding  94962  to  bjnvmpc  resulting in  1151834
# Adding  94962  to  fnnjdr  resulting in  1151834
# Adding  94962  to  jstfcllw  resulting in  1151834
# Adding  94962  to  /  resulting in  30373043
# Adding  23262  to  llpmvt  resulting in  23262
# Adding  23262  to  rhzsnr  resulting in  970776
# Adding  23262  to  bjnvmpc  resulting in  1175096
# Adding  23262  to  fnnjdr  resulting in  1175096
# Adding  23262  to  jstfcllw  resulting in  1175096
# Adding  23262  to  /  resulting in  30396305
# Adding  267083  to  llpmvt  resulting in  290345
# Adding  267083  to  rhzsnr  resulting in  1237859
# Adding  267083  to  bjnvmpc  resulting in  1442179
# Adding  267083  to  fnnjdr  resulting in  1442179
# Adding  267083  to  jstfcllw  resulting in  1442179
# Adding  267083  to  /  resulting in  30663388
# Adding  211744  to  bjnvmpc  resulting in  211744
# Adding  211744  to  llpmvt  resulting in  502089
# Adding  211744  to  rhzsnr  resulting in  1449603
# Adding  211744  to  bjnvmpc  resulting in  1653923
# Adding  211744  to  fnnjdr  resulting in  1653923
# Adding  211744  to  jstfcllw  resulting in  1653923
# Adding  211744  to  /  resulting in  30875132
# Adding  57871  to  gdjshcz  resulting in  57871
# Adding  57871  to  llpmvt  resulting in  559960
# Adding  57871  to  rhzsnr  resulting in  1507474
# Adding  57871  to  bjnvmpc  resulting in  1711794
# Adding  57871  to  fnnjdr  resulting in  1711794
# Adding  57871  to  jstfcllw  resulting in  1711794
# Adding  57871  to  /  resulting in  30933003
# Adding  254070  to  fdz  resulting in  254070
# Adding  254070  to  nqrwdstp  resulting in  254070
# Adding  254070  to  ngl  resulting in  254070
# Adding  254070  to  gtrdds  resulting in  254070
# Adding  254070  to  llpmvt  resulting in  814030
# Adding  254070  to  rhzsnr  resulting in  1761544
# Adding  254070  to  bjnvmpc  resulting in  1965864
# Adding  254070  to  fnnjdr  resulting in  1965864
# Adding  254070  to  jstfcllw  resulting in  1965864
# Adding  254070  to  /  resulting in  31187073
# Adding  245064  to  llpmvt  resulting in  245064
# Adding  245064  to  nhwvgjcq  resulting in  245064
# Adding  245064  to  llpmvt  resulting in  1059094
# Adding  245064  to  rhzsnr  resulting in  2006608
# Adding  245064  to  bjnvmpc  resulting in  2210928
# Adding  245064  to  fnnjdr  resulting in  2210928
# Adding  245064  to  jstfcllw  resulting in  2210928
# Adding  245064  to  /  resulting in  31432137
# Adding  39334  to  sbsqrg  resulting in  39334
# Adding  39334  to  rhzsnr  resulting in  2045942
# Adding  39334  to  bjnvmpc  resulting in  2250262
# Adding  39334  to  fnnjdr  resulting in  2250262
# Adding  39334  to  jstfcllw  resulting in  2250262
# Adding  39334  to  /  resulting in  31471471
# Adding  249206  to  ccbn  resulting in  249206
# Adding  249206  to  fnnjdr  resulting in  2499468
# Adding  249206  to  jstfcllw  resulting in  2499468
# Adding  249206  to  /  resulting in  31720677
# Adding  174074  to  ccbn  resulting in  423280
# Adding  174074  to  fnnjdr  resulting in  2673542
# Adding  174074  to  jstfcllw  resulting in  2673542
# Adding  174074  to  /  resulting in  31894751
# Adding  255071  to  ccbn  resulting in  678351
# Adding  255071  to  fnnjdr  resulting in  2928613
# Adding  255071  to  jstfcllw  resulting in  2928613
# Adding  255071  to  /  resulting in  32149822
# Adding  112408  to  ccbn  resulting in  790759
# Adding  112408  to  fnnjdr  resulting in  3041021
# Adding  112408  to  jstfcllw  resulting in  3041021
# Adding  112408  to  /  resulting in  32262230
# Adding  57326  to  ccbn  resulting in  848085
# Adding  57326  to  fnnjdr  resulting in  3098347
# Adding  57326  to  jstfcllw  resulting in  3098347
# Adding  57326  to  /  resulting in  32319556
# Adding  86067  to  tfsgzdsl  resulting in  86067
# Adding  86067  to  ccbn  resulting in  934152
# Adding  86067  to  fnnjdr  resulting in  3184414
# Adding  86067  to  jstfcllw  resulting in  3184414
# Adding  86067  to  /  resulting in  32405623
# Adding  177455  to  tfsgzdsl  resulting in  263522
# Adding  177455  to  ccbn  resulting in  1111607
# Adding  177455  to  fnnjdr  resulting in  3361869
# Adding  177455  to  jstfcllw  resulting in  3361869
# Adding  177455  to  /  resulting in  32583078
# Adding  136706  to  btjdllpn  resulting in  136706
# Adding  136706  to  llpmvt  resulting in  136706
# Adding  136706  to  fnnjdr  resulting in  3498575
# Adding  136706  to  jstfcllw  resulting in  3498575
# Adding  136706  to  /  resulting in  32719784
# Adding  44873  to  zgt  resulting in  44873
# Adding  44873  to  llpmvt  resulting in  181579
# Adding  44873  to  fnnjdr  resulting in  3543448
# Adding  44873  to  jstfcllw  resulting in  3543448
# Adding  44873  to  /  resulting in  32764657
# Adding  5472  to  llpmvt  resulting in  5472
# Adding  5472  to  jstfcllw  resulting in  3548920
# Adding  5472  to  /  resulting in  32770129
# Adding  128075  to  llpmvt  resulting in  133547
# Adding  128075  to  jstfcllw  resulting in  3676995
# Adding  128075  to  /  resulting in  32898204
# Adding  138116  to  llpmvt  resulting in  271663
# Adding  138116  to  jstfcllw  resulting in  3815111
# Adding  138116  to  /  resulting in  33036320
# Adding  284468  to  lpbrvhw  resulting in  284468
# Adding  284468  to  jstfcllw  resulting in  4099579
# Adding  284468  to  /  resulting in  33320788
# Adding  46353  to  lpbrvhw  resulting in  330821
# Adding  46353  to  jstfcllw  resulting in  4145932
# Adding  46353  to  /  resulting in  33367141
# Adding  89993  to  pszldqqh  resulting in  89993
# Adding  89993  to  lpbrvhw  resulting in  420814
# Adding  89993  to  jstfcllw  resulting in  4235925
# Adding  89993  to  /  resulting in  33457134
# Adding  104582  to  wdlp  resulting in  104582
# Adding  104582  to  lpbrvhw  resulting in  525396
# Adding  104582  to  jstfcllw  resulting in  4340507
# Adding  104582  to  /  resulting in  33561716
# Adding  208979  to  wdlp  resulting in  313561
# Adding  208979  to  lpbrvhw  resulting in  734375
# Adding  208979  to  jstfcllw  resulting in  4549486
# Adding  208979  to  /  resulting in  33770695
# Adding  136509  to  wdlp  resulting in  450070
# Adding  136509  to  lpbrvhw  resulting in  870884
# Adding  136509  to  jstfcllw  resulting in  4685995
# Adding  136509  to  /  resulting in  33907204
# Adding  30250  to  jsnfn  resulting in  30250
# Adding  30250  to  pnrbvd  resulting in  30250
# Adding  30250  to  jstfcllw  resulting in  4716245
# Adding  30250  to  /  resulting in  33937454
# Adding  270898  to  smhjmb  resulting in  270898
# Adding  270898  to  pnrbvd  resulting in  301148
# Adding  270898  to  jstfcllw  resulting in  4987143
# Adding  270898  to  /  resulting in  34208352
# Adding  63893  to  smhjmb  resulting in  334791
# Adding  63893  to  pnrbvd  resulting in  365041
# Adding  63893  to  jstfcllw  resulting in  5051036
# Adding  63893  to  /  resulting in  34272245
# Adding  242417  to  lhltq  resulting in  242417
# Adding  242417  to  /  resulting in  34514662
# Adding  183883  to  lhltq  resulting in  426300
# Adding  183883  to  /  resulting in  34698545
# Adding  153306  to  dqqcgn  resulting in  153306
# Adding  153306  to  lhltq  resulting in  579606
# Adding  153306  to  /  resulting in  34851851
# Adding  99780  to  dqqcgn  resulting in  253086
# Adding  99780  to  lhltq  resulting in  679386
# Adding  99780  to  /  resulting in  34951631
# Adding  79041  to  jstfcllw  resulting in  79041
# Adding  79041  to  lhltq  resulting in  758427
# Adding  79041  to  /  resulting in  35030672
# Adding  148785  to  jstfcllw  resulting in  227826
# Adding  148785  to  lhltq  resulting in  907212
# Adding  148785  to  /  resulting in  35179457
# Adding  236989  to  jstfcllw  resulting in  464815
# Adding  236989  to  lhltq  resulting in  1144201
# Adding  236989  to  /  resulting in  35416446
# Adding  127036  to  jdssgdpv  resulting in  127036
# Adding  127036  to  jstfcllw  resulting in  591851
# Adding  127036  to  lhltq  resulting in  1271237
# Adding  127036  to  /  resulting in  35543482
# Adding  107115  to  jdssgdpv  resulting in  234151
# Adding  107115  to  jstfcllw  resulting in  698966
# Adding  107115  to  lhltq  resulting in  1378352
# Adding  107115  to  /  resulting in  35650597
# Adding  91006  to  nmsvc  resulting in  91006
# Adding  91006  to  jstfcllw  resulting in  789972
# Adding  91006  to  lhltq  resulting in  1469358
# Adding  91006  to  /  resulting in  35741603
# Adding  206666  to  nmsvc  resulting in  297672
# Adding  206666  to  jstfcllw  resulting in  996638
# Adding  206666  to  lhltq  resulting in  1676024
# Adding  206666  to  /  resulting in  35948269
# Adding  44003  to  wwvlv  resulting in  44003
# Adding  44003  to  lhltq  resulting in  1720027
# Adding  44003  to  /  resulting in  35992272
# Adding  48099  to  jstfcllw  resulting in  48099
# Adding  48099  to  wwvlv  resulting in  92102
# Adding  48099  to  lhltq  resulting in  1768126
# Adding  48099  to  /  resulting in  36040371
# Adding  179597  to  llpmvt  resulting in  179597
# Adding  179597  to  /  resulting in  36219968
# Adding  220080  to  ndn  resulting in  220080
# Adding  220080  to  llpmvt  resulting in  399677
# Adding  220080  to  /  resulting in  36440048
# Adding  190391  to  ndn  resulting in  410471
# Adding  190391  to  llpmvt  resulting in  590068
# Adding  190391  to  /  resulting in  36630439
# Adding  113172  to  ndn  resulting in  523643
# Adding  113172  to  llpmvt  resulting in  703240
# Adding  113172  to  /  resulting in  36743611
# Adding  33050  to  ndn  resulting in  556693
# Adding  33050  to  llpmvt  resulting in  736290
# Adding  33050  to  /  resulting in  36776661
# Adding  53361  to  tgmt  resulting in  53361
# Adding  53361  to  /  resulting in  36830022
# Adding  44579  to  tgmt  resulting in  97940
# Adding  44579  to  /  resulting in  36874601
# Adding  182848  to  wcbq  resulting in  182848
# Adding  182848  to  /  resulting in  37057449
# Adding  224127  to  bjnvmpc  resulting in  224127
# Adding  224127  to  wcbq  resulting in  406975
# Adding  224127  to  /  resulting in  37281576
# Adding  267019  to  bjnvmpc  resulting in  491146
# Adding  267019  to  wcbq  resulting in  673994
# Adding  267019  to  /  resulting in  37548595
# Adding  263703  to  bjnvmpc  resulting in  754849
# Adding  263703  to  wcbq  resulting in  937697
# Adding  263703  to  /  resulting in  37812298
# Adding  3983  to  bjnvmpc  resulting in  758832
# Adding  3983  to  wcbq  resulting in  941680
# Adding  3983  to  /  resulting in  37816281
# Adding  167421  to  glwzwcvm  resulting in  167421
# Adding  167421  to  bjnvmpc  resulting in  926253
# Adding  167421  to  wcbq  resulting in  1109101
# Adding  167421  to  /  resulting in  37983702
# Adding  167790  to  llpmvt  resulting in  167790
# Adding  167790  to  glwzwcvm  resulting in  335211
# Adding  167790  to  bjnvmpc  resulting in  1094043
# Adding  167790  to  wcbq  resulting in  1276891
# Adding  167790  to  /  resulting in  38151492
# Adding  91994  to  hrjjrrvl  resulting in  91994
# Adding  91994  to  bjnvmpc  resulting in  1186037
# Adding  91994  to  wcbq  resulting in  1368885
# Adding  91994  to  /  resulting in  38243486
# Adding  2227  to  hrjjrrvl  resulting in  94221
# Adding  2227  to  bjnvmpc  resulting in  1188264
# Adding  2227  to  wcbq  resulting in  1371112
# Adding  2227  to  /  resulting in  38245713
# Adding  165605  to  nqbrm  resulting in  165605
# Adding  165605  to  bjnvmpc  resulting in  1353869
# Adding  165605  to  wcbq  resulting in  1536717
# Adding  165605  to  /  resulting in  38411318
# Adding  163111  to  cfdn  resulting in  163111
# Adding  163111  to  cnwczqp  resulting in  163111
# Adding  163111  to  wcbq  resulting in  1699828
# Adding  163111  to  /  resulting in  38574429
# Adding  257093  to  bjnvmpc  resulting in  257093
# Adding  257093  to  cfdn  resulting in  420204
# Adding  257093  to  cnwczqp  resulting in  420204
# Adding  257093  to  wcbq  resulting in  1956921
# Adding  257093  to  /  resulting in  38831522
# Adding  219526  to  phtt  resulting in  219526
# Adding  219526  to  cfdn  resulting in  639730
# Adding  219526  to  cnwczqp  resulting in  639730
# Adding  219526  to  wcbq  resulting in  2176447
# Adding  219526  to  /  resulting in  39051048
# Adding  135287  to  wjzzvs  resulting in  135287
# Adding  135287  to  jdh  resulting in  135287
# Adding  135287  to  cnwczqp  resulting in  775017
# Adding  135287  to  wcbq  resulting in  2311734
# Adding  135287  to  /  resulting in  39186335
# Adding  86191  to  vmwvpjn  resulting in  86191
# Adding  86191  to  dpgwtwp  resulting in  86191
# Adding  86191  to  wcbq  resulting in  2397925
# Adding  86191  to  /  resulting in  39272526
# Adding  140007  to  vmwvpjn  resulting in  226198
# Adding  140007  to  dpgwtwp  resulting in  226198
# Adding  140007  to  wcbq  resulting in  2537932
# Adding  140007  to  /  resulting in  39412533
# Adding  128243  to  vmwvpjn  resulting in  354441
# Adding  128243  to  dpgwtwp  resulting in  354441
# Adding  128243  to  wcbq  resulting in  2666175
# Adding  128243  to  /  resulting in  39540776
# Adding  8694  to  bjnvmpc  resulting in  8694
# Adding  8694  to  vmwvpjn  resulting in  363135
# Adding  8694  to  dpgwtwp  resulting in  363135
# Adding  8694  to  wcbq  resulting in  2674869
# Adding  8694  to  /  resulting in  39549470
# Adding  166456  to  bjnvmpc  resulting in  175150
# Adding  166456  to  vmwvpjn  resulting in  529591
# Adding  166456  to  dpgwtwp  resulting in  529591
# Adding  166456  to  wcbq  resulting in  2841325
# Adding  166456  to  /  resulting in  39715926
# Adding  231856  to  gtsf  resulting in  231856
# Adding  231856  to  wcbq  resulting in  3073181
# Adding  231856  to  /  resulting in  39947782
# Adding  225380  to  gtsf  resulting in  457236
# Adding  225380  to  wcbq  resulting in  3298561
# Adding  225380  to  /  resulting in  40173162
# Adding  279010  to  gtsf  resulting in  736246
# Adding  279010  to  wcbq  resulting in  3577571
# Adding  279010  to  /  resulting in  40452172
# Adding  143990  to  llpmvt  resulting in  143990
# Adding  143990  to  gtsf  resulting in  880236
# Adding  143990  to  wcbq  resulting in  3721561
# Adding  143990  to  /  resulting in  40596162
# Adding  158450  to  pnrbvd  resulting in  158450
# Adding  158450  to  llpmvt  resulting in  302440
# Adding  158450  to  gtsf  resulting in  1038686
# Adding  158450  to  wcbq  resulting in  3880011
# Adding  158450  to  /  resulting in  40754612
# Adding  147513  to  pqm  resulting in  147513
# Adding  147513  to  gtsf  resulting in  1186199
# Adding  147513  to  wcbq  resulting in  4027524
# Adding  147513  to  /  resulting in  40902125
# Adding  170386  to  znlgg  resulting in  170386
# Adding  170386  to  nmsvc  resulting in  170386
# Adding  170386  to  wcbq  resulting in  4197910
# Adding  170386  to  /  resulting in  41072511

# %%
for pre, fill, node in RenderTree(root):
    print(f"{pre} {node.name}")
# Out:
#  {'dirname': '/', 'size': 41072511}
# ├──  {'dirname': 'cwdpn', 'size': 19935440}
# │   ├──  {'dirname': 'mnm', 'size': 1695866}
# │   │   ├──  {'filename': 'grgj', 'size': 82227}
# │   │   ├──  {'dirname': 'plldwn', 'size': 805305}
# │   │   │   ├──  {'filename': 'gtpgsvv.jch', 'size': 114478}
# │   │   │   ├──  {'filename': 'gzggrfm.rtw', 'size': 58874}
# │   │   │   ├──  {'filename': 'nrsrmplp', 'size': 247491}
# │   │   │   ├──  {'filename': 'nzrdgsgm.fzh', 'size': 114552}
# │   │   │   └──  {'dirname': 'prwm', 'size': 269910}
# │   │   │       └──  {'filename': 'rpglpmr.zbh', 'size': 269910}
# │   │   ├──  {'dirname': 'rtpjd', 'size': 164458}
# │   │   │   ├──  {'filename': 'wfjltczw.qnc', 'size': 65341}
# │   │   │   └──  {'dirname': 'pnrbvd', 'size': 99117}
# │   │   │       └──  {'filename': 'rpglpmr.zbh', 'size': 99117}
# │   │   └──  {'dirname': 'shvplq', 'size': 643876}
# │   │       ├──  {'filename': 'glghcqs', 'size': 192167}
# │   │       ├──  {'filename': 'gvzbt', 'size': 182737}
# │   │       ├──  {'filename': 'pnrbvd', 'size': 175694}
# │   │       └──  {'filename': 'tmz', 'size': 93278}
# │   ├──  {'dirname': 'nmsvc', 'size': 17474334}
# │   │   ├──  {'filename': 'czqnrq', 'size': 59203}
# │   │   ├──  {'filename': 'qrjzrq', 'size': 49699}
# │   │   ├──  {'filename': 'rmfqqbsj.rzn', 'size': 221657}
# │   │   ├──  {'filename': 'rzbgdgp.rpn', 'size': 45989}
# │   │   ├──  {'dirname': 'bjnvmpc', 'size': 816484}
# │   │   │   ├──  {'filename': 'gclrw.gzs', 'size': 181885}
# │   │   │   ├──  {'dirname': 'gfjts', 'size': 236177}
# │   │   │   │   └──  {'filename': 'grgj', 'size': 236177}
# │   │   │   ├──  {'dirname': 'hqlmzshr', 'size': 228388}
# │   │   │   │   └──  {'filename': 'gpqcdjhl.ctd', 'size': 228388}
# │   │   │   └──  {'dirname': 'smqzqrm', 'size': 170034}
# │   │   │       └──  {'filename': 'dqvvd', 'size': 170034}
# │   │   ├──  {'dirname': 'jstfcllw', 'size': 634380}
# │   │   │   └──  {'dirname': 'bjnvmpc', 'size': 634380}
# │   │   │       ├──  {'filename': 'lzd', 'size': 204754}
# │   │   │       ├──  {'filename': 'pnrbvd', 'size': 48598}
# │   │   │       ├──  {'filename': 'vmn', 'size': 211685}
# │   │   │       └──  {'dirname': 'fmjlrc', 'size': 169343}
# │   │   │           └──  {'filename': 'rpglpmr.zbh', 'size': 169343}
# │   │   ├──  {'dirname': 'jtqgbwhb', 'size': 1912274}
# │   │   │   ├──  {'filename': 'rqplnfz.dpq', 'size': 179486}
# │   │   │   ├──  {'dirname': 'bjnvmpc', 'size': 1057360}
# │   │   │   │   ├──  {'filename': 'pnrbvd.tsw', 'size': 76133}
# │   │   │   │   ├──  {'filename': 'strq.pjn', 'size': 266667}
# │   │   │   │   ├──  {'filename': 'zvzhfjq.vwv', 'size': 242869}
# │   │   │   │   ├──  {'dirname': 'dbglngc', 'size': 369011}
# │   │   │   │   │   ├──  {'filename': 'wddhnvl.lsq', 'size': 253571}
# │   │   │   │   │   ├──  {'dirname': 'hbfbvdr', 'size': 36586}
# │   │   │   │   │   │   └──  {'filename': 'nmsvc.mpf', 'size': 36586}
# │   │   │   │   │   └──  {'dirname': 'tlsd', 'size': 78854}
# │   │   │   │   │       └──  {'filename': 'phd.phb', 'size': 78854}
# │   │   │   │   └──  {'dirname': 'rdb', 'size': 102680}
# │   │   │   │       └──  {'filename': 'drz.gjs', 'size': 102680}
# │   │   │   ├──  {'dirname': 'ddjpm', 'size': 385070}
# │   │   │   │   ├──  {'filename': 'cbc.rtp', 'size': 227450}
# │   │   │   │   ├──  {'filename': 'ltnhnzg.gqb', 'size': 71376}
# │   │   │   │   └──  {'filename': 'vpr', 'size': 86244}
# │   │   │   └──  {'dirname': 'fmtpwm', 'size': 290358}
# │   │   │       ├──  {'filename': 'grgj', 'size': 65644}
# │   │   │       ├──  {'filename': 'swffpq.nnc', 'size': 92435}
# │   │   │       └──  {'dirname': 'ggpctlh', 'size': 132279}
# │   │   │           ├──  {'filename': 'gdc', 'size': 104193}
# │   │   │           └──  {'dirname': 'rdmgrtzl', 'size': 28086}
# │   │   │               └──  {'filename': 'swffpq.nnc', 'size': 28086}
# │   │   ├──  {'dirname': 'ltqjb', 'size': 11347870}
# │   │   │   ├──  {'dirname': 'jstfcllw', 'size': 165962}
# │   │   │   │   └──  {'filename': 'rsrsnh.fjf', 'size': 165962}
# │   │   │   ├──  {'dirname': 'qjgbt', 'size': 743378}
# │   │   │   │   └──  {'dirname': 'vjrdcjbr', 'size': 743378}
# │   │   │   │       ├──  {'dirname': 'swvlpql', 'size': 457542}
# │   │   │   │       │   ├──  {'dirname': 'lqrf', 'size': 26615}
# │   │   │   │       │   │   └──  {'filename': 'hbjtfmfw.bbs', 'size': 26615}
# │   │   │   │       │   ├──  {'dirname': 'nmsvc', 'size': 321849}
# │   │   │   │       │   │   ├──  {'filename': 'bpfj', 'size': 23820}
# │   │   │   │       │   │   ├──  {'filename': 'llpmvt.hhm', 'size': 77703}
# │   │   │   │       │   │   └──  {'filename': 'tbbvnzvq', 'size': 220326}
# │   │   │   │       │   └──  {'dirname': 'wnvtfmfw', 'size': 109078}
# │   │   │   │       │       └──  {'filename': 'rpglpmr.zbh', 'size': 109078}
# │   │   │   │       └──  {'dirname': 'wmm', 'size': 285836}
# │   │   │   │           └──  {'dirname': 'nmsvc', 'size': 285836}
# │   │   │   │               └──  {'filename': 'zqhwwt.vnj', 'size': 285836}
# │   │   │   └──  {'dirname': 'rstzf', 'size': 10438530}
# │   │   │       ├──  {'filename': 'qfnjbcb.pdr', 'size': 226698}
# │   │   │       ├──  {'filename': 'swffpq.nnc', 'size': 234472}
# │   │   │       ├──  {'dirname': 'bjnvmpc', 'size': 4130397}
# │   │   │       │   ├──  {'filename': 'jstfcllw.wgq', 'size': 118290}
# │   │   │       │   ├──  {'dirname': 'mtctn', 'size': 1042330}
# │   │   │       │   │   ├──  {'filename': 'jstfcllw', 'size': 230555}
# │   │   │       │   │   ├──  {'dirname': 'nfb', 'size': 656697}
# │   │   │       │   │   │   ├──  {'filename': 'grgj', 'size': 227496}
# │   │   │       │   │   │   ├──  {'filename': 'mjwp', 'size': 154342}
# │   │   │       │   │   │   ├──  {'dirname': 'bqjczmcr', 'size': 19020}
# │   │   │       │   │   │   │   └──  {'filename': 'fzqd', 'size': 19020}
# │   │   │       │   │   │   └──  {'dirname': 'brhvhl', 'size': 255839}
# │   │   │       │   │   │       └──  {'filename': 'vtvhvh', 'size': 255839}
# │   │   │       │   │   └──  {'dirname': 'pfqv', 'size': 155078}
# │   │   │       │   │       └──  {'filename': 'ftccr.qlz', 'size': 155078}
# │   │   │       │   ├──  {'dirname': 'rjcpn', 'size': 1715364}
# │   │   │       │   │   ├──  {'filename': 'fvr.smf', 'size': 180441}
# │   │   │       │   │   ├──  {'filename': 'npbmlv.zst', 'size': 139942}
# │   │   │       │   │   ├──  {'filename': 'rjg.jqj', 'size': 237442}
# │   │   │       │   │   ├──  {'filename': 'wnwgz.qjp', 'size': 192628}
# │   │   │       │   │   ├──  {'dirname': 'ggjrm', 'size': 188844}
# │   │   │       │   │   │   └──  {'dirname': 'drjzphm', 'size': 188844}
# │   │   │       │   │   │       └──  {'filename': 'wbzh.nzw', 'size': 188844}
# │   │   │       │   │   └──  {'dirname': 'llpmvt', 'size': 776067}
# │   │   │       │   │       ├──  {'filename': 'llpmvt.ldp', 'size': 10806}
# │   │   │       │   │       ├──  {'filename': 'nmsvc', 'size': 31293}
# │   │   │       │   │       ├──  {'dirname': 'bhdpfpb', 'size': 78642}
# │   │   │       │   │       │   └──  {'filename': 'wjlwf', 'size': 78642}
# │   │   │       │   │       ├──  {'dirname': 'jstfcllw', 'size': 234658}
# │   │   │       │   │       │   └──  {'filename': 'qrdfwls.ncz', 'size': 234658}
# │   │   │       │   │       ├──  {'dirname': 'pvz', 'size': 194879}
# │   │   │       │   │       │   └──  {'filename': 'nfjsfjvt.zln', 'size': 194879}
# │   │   │       │   │       └──  {'dirname': 'qntnwf', 'size': 225789}
# │   │   │       │   │           └──  {'filename': 'mngq.qqb', 'size': 225789}
# │   │   │       │   └──  {'dirname': 'tbrccw', 'size': 1254413}
# │   │   │       │       ├──  {'filename': 'npbmlv.zst', 'size': 136331}
# │   │   │       │       ├──  {'filename': 'rpglpmr.zbh', 'size': 130573}
# │   │   │       │       ├──  {'dirname': 'llpmvt', 'size': 271647}
# │   │   │       │       │   └──  {'dirname': 'bjnvmpc', 'size': 271647}
# │   │   │       │       │       └──  {'filename': 'cdt.scr', 'size': 271647}
# │   │   │       │       ├──  {'dirname': 'nmsvc', 'size': 445771}
# │   │   │       │       │   ├──  {'filename': 'llpmvt', 'size': 185622}
# │   │   │       │       │   ├──  {'filename': 'npbmlv.zst', 'size': 102596}
# │   │   │       │       │   ├──  {'filename': 'wnwgz.qjp', 'size': 240}
# │   │   │       │       │   └──  {'filename': 'zlgplvb', 'size': 157313}
# │   │   │       │       └──  {'dirname': 'scpwzh', 'size': 270091}
# │   │   │       │           └──  {'filename': 'tncccs.lgn', 'size': 270091}
# │   │   │       ├──  {'dirname': 'fwmvpthq', 'size': 2676851}
# │   │   │       │   ├──  {'filename': 'png.zts', 'size': 109316}
# │   │   │       │   ├──  {'filename': 'qnqjmn', 'size': 90010}
# │   │   │       │   ├──  {'filename': 'rpglpmr.zbh', 'size': 193177}
# │   │   │       │   ├──  {'filename': 'rwvbqll.gvg', 'size': 283398}
# │   │   │       │   ├──  {'dirname': 'llpmvt', 'size': 840655}
# │   │   │       │   │   ├──  {'filename': 'fblf.dlq', 'size': 59723}
# │   │   │       │   │   └──  {'dirname': 'bgvjb', 'size': 780932}
# │   │   │       │   │       ├──  {'dirname': 'gjtj', 'size': 74258}
# │   │   │       │   │       │   └──  {'filename': 'mqd.jpq', 'size': 74258}
# │   │   │       │   │       ├──  {'dirname': 'nmsvc', 'size': 514861}
# │   │   │       │   │       │   ├──  {'filename': 'dqcl.gzn', 'size': 227910}
# │   │   │       │   │       │   └──  {'filename': 'llpmvt.sdv', 'size': 286951}
# │   │   │       │   │       └──  {'dirname': 'wrwsn', 'size': 191813}
# │   │   │       │   │           └──  {'filename': 'qjhfjfmb.dms', 'size': 191813}
# │   │   │       │   ├──  {'dirname': 'nmsvc', 'size': 269685}
# │   │   │       │   │   ├──  {'filename': 'llpmvt.tms', 'size': 7096}
# │   │   │       │   │   ├──  {'filename': 'nfgvtghz.gws', 'size': 102123}
# │   │   │       │   │   └──  {'filename': 'swffpq.nnc', 'size': 160466}
# │   │   │       │   ├──  {'dirname': 'ntmfpmr', 'size': 266774}
# │   │   │       │   │   └──  {'filename': 'llpmvt', 'size': 266774}
# │   │   │       │   ├──  {'dirname': 'pnrbvd', 'size': 511329}
# │   │   │       │   │   ├──  {'filename': 'pnrbvd.bmg', 'size': 181175}
# │   │   │       │   │   ├──  {'filename': 'qpw.vtm', 'size': 164233}
# │   │   │       │   │   ├──  {'dirname': 'bbpq', 'size': 125821}
# │   │   │       │   │   │   └──  {'filename': 'nbc', 'size': 125821}
# │   │   │       │   │   └──  {'dirname': 'nmsvc', 'size': 40100}
# │   │   │       │   │       └──  {'filename': 'wthm.twj', 'size': 40100}
# │   │   │       │   └──  {'dirname': 'shgtbbfw', 'size': 112507}
# │   │   │       │       └──  {'dirname': 'zpjqjtsl', 'size': 112507}
# │   │   │       │           └──  {'filename': 'wnwgz.qjp', 'size': 112507}
# │   │   │       ├──  {'dirname': 'llpmvt', 'size': 1866980}
# │   │   │       │   ├──  {'filename': 'gvgstl', 'size': 199105}
# │   │   │       │   ├──  {'filename': 'npbmlv.zst', 'size': 133701}
# │   │   │       │   ├──  {'filename': 'rpglpmr.zbh', 'size': 102349}
# │   │   │       │   ├──  {'dirname': 'nmsvc', 'size': 265877}
# │   │   │       │   │   ├──  {'filename': 'cbrggdvl.glv', 'size': 89208}
# │   │   │       │   │   └──  {'filename': 'dzm.hlr', 'size': 176669}
# │   │   │       │   └──  {'dirname': 'pnrbvd', 'size': 1165948}
# │   │   │       │       ├──  {'filename': 'llpmvt.wwb', 'size': 178532}
# │   │   │       │       ├──  {'dirname': 'hchfn', 'size': 332934}
# │   │   │       │       │   ├──  {'filename': 'jpzqrgfn.jhl', 'size': 51572}
# │   │   │       │       │   └──  {'filename': 'qntdtr.jtc', 'size': 281362}
# │   │   │       │       └──  {'dirname': 'llpmvt', 'size': 654482}
# │   │   │       │           ├──  {'filename': 'cdvpwbj', 'size': 63202}
# │   │   │       │           ├──  {'filename': 'sjs.dql', 'size': 255774}
# │   │   │       │           ├──  {'filename': 'wnwgz.qjp', 'size': 60903}
# │   │   │       │           └──  {'filename': 'zbhwbff', 'size': 274603}
# │   │   │       ├──  {'dirname': 'mpz', 'size': 419918}
# │   │   │       │   ├──  {'dirname': 'gdfwttff', 'size': 40626}
# │   │   │       │   │   └──  {'filename': 'rpglpmr.zbh', 'size': 40626}
# │   │   │       │   ├──  {'dirname': 'njptwz', 'size': 69007}
# │   │   │       │   │   └──  {'dirname': 'jstfcllw', 'size': 69007}
# │   │   │       │   │       └──  {'filename': 'grgj', 'size': 69007}
# │   │   │       │   ├──  {'dirname': 'pnrbvd', 'size': 153157}
# │   │   │       │   │   └──  {'filename': 'rjvtctv', 'size': 153157}
# │   │   │       │   └──  {'dirname': 'zcvn', 'size': 157128}
# │   │   │       │       └──  {'filename': 'llpmvt.swg', 'size': 157128}
# │   │   │       ├──  {'dirname': 'qpvnfl', 'size': 234947}
# │   │   │       │   └──  {'filename': 'jstfcllw', 'size': 234947}
# │   │   │       └──  {'dirname': 'rmrngqdg', 'size': 648267}
# │   │   │           ├──  {'filename': 'llpmvt', 'size': 80105}
# │   │   │           ├──  {'filename': 'llpmvt.plc', 'size': 185789}
# │   │   │           ├──  {'dirname': 'bjnvmpc', 'size': 181438}
# │   │   │           │   └──  {'filename': 'swffpq.nnc', 'size': 181438}
# │   │   │           └──  {'dirname': 'wvg', 'size': 200935}
# │   │   │               ├──  {'filename': 'ppcjtdbd.blr', 'size': 191048}
# │   │   │               └──  {'dirname': 'hlwjtqzj', 'size': 9887}
# │   │   │                   └──  {'filename': 'pnrbvd.psv', 'size': 9887}
# │   │   ├──  {'dirname': 'tmrn', 'size': 930256}
# │   │   │   ├──  {'filename': 'dbwl', 'size': 271916}
# │   │   │   ├──  {'filename': 'gcfhvjj', 'size': 9555}
# │   │   │   ├──  {'filename': 'grgj', 'size': 198388}
# │   │   │   ├──  {'filename': 'pnrbvd.qbj', 'size': 246330}
# │   │   │   └──  {'dirname': 'zzmpts', 'size': 204067}
# │   │   │       └──  {'dirname': 'zmsbdc', 'size': 204067}
# │   │   │           └──  {'filename': 'swffpq.nnc', 'size': 204067}
# │   │   └──  {'dirname': 'vzvwphz', 'size': 1456522}
# │   │       ├──  {'filename': 'wnwgz.qjp', 'size': 103462}
# │   │       ├──  {'dirname': 'nmsvc', 'size': 493311}
# │   │       │   ├──  {'dirname': 'bqvdvllf', 'size': 216038}
# │   │       │   │   ├──  {'filename': 'grgj', 'size': 61744}
# │   │       │   │   └──  {'filename': 'lsmjt', 'size': 154294}
# │   │       │   └──  {'dirname': 'ghdlvvfs', 'size': 277273}
# │   │       │       └──  {'filename': 'nmsvc.nwd', 'size': 277273}
# │   │       ├──  {'dirname': 'ntmmcjh', 'size': 267092}
# │   │       │   ├──  {'filename': 'ffdgnspv.bhb', 'size': 124476}
# │   │       │   ├──  {'filename': 'jstfcllw.phg', 'size': 110867}
# │   │       │   ├──  {'filename': 'jstfcllw.vbf', 'size': 12568}
# │   │       │   └──  {'filename': 'npbmlv.zst', 'size': 19181}
# │   │       └──  {'dirname': 'rvwjl', 'size': 592657}
# │   │           ├──  {'filename': 'jstfcllw.fhg', 'size': 57593}
# │   │           ├──  {'filename': 'jstfcllw.gwq', 'size': 221008}
# │   │           ├──  {'filename': 'lwrbqz.dqm', 'size': 12478}
# │   │           ├──  {'filename': 'rsrjp.hvp', 'size': 149624}
# │   │           └──  {'dirname': 'jstfcllw', 'size': 151954}
# │   │               ├──  {'filename': 'pnrbvd', 'size': 131800}
# │   │               └──  {'filename': 'wnwgz.qjp', 'size': 20154}
# │   └──  {'dirname': 'rgbdq', 'size': 765240}
# │       ├──  {'filename': 'ffqnrsh.qmc', 'size': 135946}
# │       ├──  {'filename': 'grgj', 'size': 186972}
# │       ├──  {'filename': 'nmsvc', 'size': 151369}
# │       ├──  {'filename': 'qgtllf', 'size': 125605}
# │       └──  {'filename': 'zhwtbml.zsz', 'size': 165348}
# ├──  {'dirname': 'drzllllv', 'size': 446356}
# │   ├──  {'filename': 'pnrbvd.gdv', 'size': 209144}
# │   └──  {'dirname': 'mzfzzgsv', 'size': 237212}
# │       └──  {'filename': 'pnrbvd.fsp', 'size': 237212}
# ├──  {'dirname': 'fqflwvh', 'size': 8582270}
# │   ├──  {'filename': 'grgj', 'size': 10557}
# │   ├──  {'filename': 'gslbvz.gch', 'size': 11071}
# │   ├──  {'filename': 'mlhnjvhq', 'size': 209490}
# │   ├──  {'filename': 'nmlcf', 'size': 99206}
# │   ├──  {'filename': 'rpglpmr.zbh', 'size': 139022}
# │   ├──  {'dirname': 'jzlgzd', 'size': 223773}
# │   │   └──  {'filename': 'zhvgczs.rwv', 'size': 223773}
# │   ├──  {'dirname': 'jzwwgjh', 'size': 80522}
# │   │   └──  {'filename': 'fvm.tdd', 'size': 80522}
# │   ├──  {'dirname': 'nfh', 'size': 7564854}
# │   │   ├──  {'filename': 'bnnb.mzf', 'size': 219887}
# │   │   ├──  {'filename': 'grgj', 'size': 145633}
# │   │   ├──  {'filename': 'llpmvt', 'size': 93312}
# │   │   ├──  {'filename': 'mfdfjzrw.lzh', 'size': 65642}
# │   │   ├──  {'filename': 'nmsvc', 'size': 269811}
# │   │   ├──  {'dirname': 'bfj', 'size': 195345}
# │   │   │   ├──  {'dirname': 'bzrfbfp', 'size': 34834}
# │   │   │   │   └──  {'filename': 'swffpq.nnc', 'size': 34834}
# │   │   │   ├──  {'dirname': 'pnrbvd', 'size': 68732}
# │   │   │   │   └──  {'filename': 'wnwgz.qjp', 'size': 68732}
# │   │   │   └──  {'dirname': 'rbq', 'size': 91779}
# │   │   │       └──  {'filename': 'grgh.vwl', 'size': 91779}
# │   │   ├──  {'dirname': 'bjnvmpc', 'size': 114048}
# │   │   │   └──  {'filename': 'jstfcllw', 'size': 114048}
# │   │   ├──  {'dirname': 'nbfsjvzn', 'size': 201923}
# │   │   │   ├──  {'filename': 'vbtsdf.dqn', 'size': 44465}
# │   │   │   └──  {'filename': 'wnwgz.qjp', 'size': 157458}
# │   │   ├──  {'dirname': 'pnrbvd', 'size': 662407}
# │   │   │   ├──  {'filename': 'dhgbmdl.lbg', 'size': 40294}
# │   │   │   ├──  {'filename': 'fbghtps', 'size': 119065}
# │   │   │   ├──  {'filename': 'glbzmbn.jqd', 'size': 271425}
# │   │   │   └──  {'filename': 'hsj.vws', 'size': 231623}
# │   │   ├──  {'dirname': 'qhn', 'size': 4720888}
# │   │   │   ├──  {'filename': 'hvcfgv', 'size': 175155}
# │   │   │   ├──  {'filename': 'llpmvt.vqf', 'size': 30969}
# │   │   │   ├──  {'filename': 'tgvzbm', 'size': 276798}
# │   │   │   ├──  {'dirname': 'fsgn', 'size': 2279622}
# │   │   │   │   ├──  {'filename': 'grgj', 'size': 30980}
# │   │   │   │   ├──  {'filename': 'hsrlwwqg', 'size': 116742}
# │   │   │   │   ├──  {'filename': 'pnrbvd.vrm', 'size': 194210}
# │   │   │   │   ├──  {'filename': 'rjwvfz', 'size': 105346}
# │   │   │   │   ├──  {'filename': 'smpnrnm', 'size': 182505}
# │   │   │   │   ├──  {'dirname': 'btpqsr', 'size': 750618}
# │   │   │   │   │   ├──  {'filename': 'brf', 'size': 98971}
# │   │   │   │   │   ├──  {'filename': 'lrpfbnht.fcz', 'size': 79166}
# │   │   │   │   │   ├──  {'filename': 'pnrbvd.gnr', 'size': 94138}
# │   │   │   │   │   ├──  {'filename': 'qhg', 'size': 288381}
# │   │   │   │   │   └──  {'dirname': 'jcj', 'size': 189962}
# │   │   │   │   │       └──  {'filename': 'npbmlv.zst', 'size': 189962}
# │   │   │   │   ├──  {'dirname': 'hjgphwdc', 'size': 72389}
# │   │   │   │   │   └──  {'filename': 'npbmlv.zst', 'size': 72389}
# │   │   │   │   └──  {'dirname': 'vwpsrq', 'size': 826832}
# │   │   │   │       ├──  {'filename': 'llpmvt.srd', 'size': 43797}
# │   │   │   │       ├──  {'dirname': 'bnqwnmg', 'size': 281017}
# │   │   │   │       │   └──  {'filename': 'lvtj.vzc', 'size': 281017}
# │   │   │   │       ├──  {'dirname': 'ljjmwc', 'size': 239040}
# │   │   │   │       │   └──  {'filename': 'fzb.rwh', 'size': 239040}
# │   │   │   │       └──  {'dirname': 'nmsvc', 'size': 262978}
# │   │   │   │           └──  {'filename': 'thrgcv.bhr', 'size': 262978}
# │   │   │   ├──  {'dirname': 'lwmccr', 'size': 166022}
# │   │   │   │   └──  {'filename': 'grgj', 'size': 166022}
# │   │   │   ├──  {'dirname': 'svzhc', 'size': 1737964}
# │   │   │   │   ├──  {'filename': 'jrhblvdc.nvm', 'size': 208916}
# │   │   │   │   ├──  {'filename': 'nmsvc.qms', 'size': 133836}
# │   │   │   │   ├──  {'filename': 'npbmlv.zst', 'size': 4542}
# │   │   │   │   ├──  {'filename': 'plwhmppw.phw', 'size': 105516}
# │   │   │   │   ├──  {'filename': 'zcdpgl.fjz', 'size': 93339}
# │   │   │   │   ├──  {'dirname': 'hpp', 'size': 1056414}
# │   │   │   │   │   ├──  {'filename': 'rggng.zbj', 'size': 35124}
# │   │   │   │   │   ├──  {'filename': 'szbqvgcg.mnc', 'size': 238667}
# │   │   │   │   │   ├──  {'dirname': 'gnj', 'size': 188603}
# │   │   │   │   │   │   └──  {'filename': 'zwdttf', 'size': 188603}
# │   │   │   │   │   ├──  {'dirname': 'nprpdwj', 'size': 149966}
# │   │   │   │   │   │   └──  {'dirname': 'jstfcllw', 'size': 149966}
# │   │   │   │   │   │       └──  {'filename': 'rpglpmr.zbh', 'size': 149966}
# │   │   │   │   │   ├──  {'dirname': 'pwg', 'size': 45034}
# │   │   │   │   │   │   └──  {'filename': 'wwpgmrhq', 'size': 45034}
# │   │   │   │   │   └──  {'dirname': 'zswbcbpz', 'size': 399020}
# │   │   │   │   │       ├──  {'filename': 'llpmvt', 'size': 269836}
# │   │   │   │   │       └──  {'filename': 'sntr', 'size': 129184}
# │   │   │   │   └──  {'dirname': 'pnrbvd', 'size': 135401}
# │   │   │   │       └──  {'filename': 'rpglpmr.zbh', 'size': 135401}
# │   │   │   └──  {'dirname': 'vblpsfqz', 'size': 54358}
# │   │   │       └──  {'filename': 'qdqrlsz.zgz', 'size': 54358}
# │   │   ├──  {'dirname': 'rphmrdnc', 'size': 189190}
# │   │   │   └──  {'filename': 'jzlgndht', 'size': 189190}
# │   │   ├──  {'dirname': 'vnjvqs', 'size': 254178}
# │   │   │   └──  {'filename': 'wnwgz.qjp', 'size': 254178}
# │   │   └──  {'dirname': 'zqgmm', 'size': 432590}
# │   │       ├──  {'filename': 'wnwgz.qjp', 'size': 85521}
# │   │       ├──  {'dirname': 'cblp', 'size': 131189}
# │   │       │   └──  {'filename': 'rpglpmr.zbh', 'size': 131189}
# │   │       └──  {'dirname': 'mvgjj', 'size': 215880}
# │   │           └──  {'filename': 'ddv', 'size': 215880}
# │   └──  {'dirname': 'pqtgln', 'size': 243775}
# │       ├──  {'filename': 'rpglpmr.zbh', 'size': 80302}
# │       ├──  {'filename': 'rrsghb.ddq', 'size': 14147}
# │       └──  {'filename': 'zsrjpr.gwp', 'size': 149326}
# ├──  {'dirname': 'jczm', 'size': 257143}
# │   └──  {'dirname': 'bhwgcrm', 'size': 257143}
# │       └──  {'filename': 'wnwgz.qjp', 'size': 257143}
# ├──  {'dirname': 'jstfcllw', 'size': 5051036}
# │   ├──  {'dirname': 'fnnjdr', 'size': 3543448}
# │   │   ├──  {'dirname': 'bjnvmpc', 'size': 2250262}
# │   │   │   ├──  {'filename': 'pnrbvd', 'size': 160613}
# │   │   │   ├──  {'dirname': 'ftlf', 'size': 43707}
# │   │   │   │   └──  {'dirname': 'rrdzzgtg', 'size': 43707}
# │   │   │   │       └──  {'filename': 'dpbchhz.jrl', 'size': 43707}
# │   │   │   └──  {'dirname': 'rhzsnr', 'size': 2045942}
# │   │   │       ├──  {'filename': 'bjnvmpc.dlz', 'size': 13607}
# │   │   │       ├──  {'filename': 'dqt.cdm', 'size': 123612}
# │   │   │       ├──  {'filename': 'grgj', 'size': 155260}
# │   │   │       ├──  {'filename': 'nmsvc', 'size': 228650}
# │   │   │       ├──  {'filename': 'swffpq.nnc', 'size': 229752}
# │   │   │       ├──  {'dirname': 'jstfcllw', 'size': 196633}
# │   │   │       │   ├──  {'filename': 'npbmlv.zst', 'size': 101671}
# │   │   │       │   └──  {'dirname': 'fcbs', 'size': 94962}
# │   │   │       │       └──  {'dirname': 'qtsrhfv', 'size': 94962}
# │   │   │       │           └──  {'filename': 'wnwgz.qjp', 'size': 94962}
# │   │   │       ├──  {'dirname': 'llpmvt', 'size': 1059094}
# │   │   │       │   ├──  {'filename': 'mzw', 'size': 23262}
# │   │   │       │   ├──  {'filename': 'npbmlv.zst', 'size': 267083}
# │   │   │       │   ├──  {'dirname': 'bjnvmpc', 'size': 211744}
# │   │   │       │   │   └──  {'filename': 'bjnvmpc', 'size': 211744}
# │   │   │       │   ├──  {'dirname': 'gdjshcz', 'size': 57871}
# │   │   │       │   │   └──  {'filename': 'swffpq.nnc', 'size': 57871}
# │   │   │       │   ├──  {'dirname': 'gtrdds', 'size': 254070}
# │   │   │       │   │   └──  {'dirname': 'ngl', 'size': 254070}
# │   │   │       │   │       └──  {'dirname': 'nqrwdstp', 'size': 254070}
# │   │   │       │   │           └──  {'dirname': 'fdz', 'size': 254070}
# │   │   │       │   │               └──  {'filename': 'wnwgz.qjp', 'size': 254070}
# │   │   │       │   └──  {'dirname': 'nhwvgjcq', 'size': 245064}
# │   │   │       │       └──  {'dirname': 'llpmvt', 'size': 245064}
# │   │   │       │           └──  {'filename': 'grgj', 'size': 245064}
# │   │   │       └──  {'dirname': 'sbsqrg', 'size': 39334}
# │   │   │           └──  {'filename': 'fcrw.wfs', 'size': 39334}
# │   │   ├──  {'dirname': 'ccbn', 'size': 1111607}
# │   │   │   ├──  {'filename': 'grgj', 'size': 249206}
# │   │   │   ├──  {'filename': 'hdjdpdrq.sdw', 'size': 174074}
# │   │   │   ├──  {'filename': 'llpmvt.wbd', 'size': 255071}
# │   │   │   ├──  {'filename': 'swffpq.nnc', 'size': 112408}
# │   │   │   ├──  {'filename': 'wwjt.hqb', 'size': 57326}
# │   │   │   └──  {'dirname': 'tfsgzdsl', 'size': 263522}
# │   │   │       ├──  {'filename': 'bjnvmpc', 'size': 86067}
# │   │   │       └──  {'filename': 'gmznt', 'size': 177455}
# │   │   └──  {'dirname': 'llpmvt', 'size': 181579}
# │   │       ├──  {'dirname': 'btjdllpn', 'size': 136706}
# │   │       │   └──  {'filename': 'btchp', 'size': 136706}
# │   │       └──  {'dirname': 'zgt', 'size': 44873}
# │   │           └──  {'filename': 'vmh.mfd', 'size': 44873}
# │   ├──  {'dirname': 'llpmvt', 'size': 271663}
# │   │   ├──  {'filename': 'ldj', 'size': 5472}
# │   │   ├──  {'filename': 'npbmlv.zst', 'size': 128075}
# │   │   └──  {'filename': 'pnrbvd.lcm', 'size': 138116}
# │   ├──  {'dirname': 'lpbrvhw', 'size': 870884}
# │   │   ├──  {'filename': 'pnrbvd.bcg', 'size': 284468}
# │   │   ├──  {'filename': 'pnrbvd.bdd', 'size': 46353}
# │   │   ├──  {'dirname': 'pszldqqh', 'size': 89993}
# │   │   │   └──  {'filename': 'wnwgz.qjp', 'size': 89993}
# │   │   └──  {'dirname': 'wdlp', 'size': 450070}
# │   │       ├──  {'filename': 'grgj', 'size': 104582}
# │   │       ├──  {'filename': 'swffpq.nnc', 'size': 208979}
# │   │       └──  {'filename': 'vhjbdgfj', 'size': 136509}
# │   └──  {'dirname': 'pnrbvd', 'size': 365041}
# │       ├──  {'dirname': 'jsnfn', 'size': 30250}
# │       │   └──  {'filename': 'rpglpmr.zbh', 'size': 30250}
# │       └──  {'dirname': 'smhjmb', 'size': 334791}
# │           ├──  {'filename': 'fpj.trq', 'size': 270898}
# │           └──  {'filename': 'wnwgz.qjp', 'size': 63893}
# ├──  {'dirname': 'lhltq', 'size': 1768126}
# │   ├──  {'filename': 'jstfcllw.ngw', 'size': 242417}
# │   ├──  {'filename': 'rpglpmr.zbh', 'size': 183883}
# │   ├──  {'dirname': 'dqqcgn', 'size': 253086}
# │   │   ├──  {'filename': 'swffpq.nnc', 'size': 153306}
# │   │   └──  {'filename': 'tpdgtnl', 'size': 99780}
# │   ├──  {'dirname': 'jstfcllw', 'size': 996638}
# │   │   ├──  {'filename': 'mhwcgqzs.mqc', 'size': 79041}
# │   │   ├──  {'filename': 'swffpq.nnc', 'size': 148785}
# │   │   ├──  {'filename': 'wnwgz.qjp', 'size': 236989}
# │   │   ├──  {'dirname': 'jdssgdpv', 'size': 234151}
# │   │   │   ├──  {'filename': 'bgjwsm.qqc', 'size': 127036}
# │   │   │   └──  {'filename': 'nmsvc.fnv', 'size': 107115}
# │   │   └──  {'dirname': 'nmsvc', 'size': 297672}
# │   │       ├──  {'filename': 'dvbqm.nfl', 'size': 91006}
# │   │       └──  {'filename': 'tsgcwc.fvj', 'size': 206666}
# │   └──  {'dirname': 'wwvlv', 'size': 92102}
# │       ├──  {'filename': 'pdq', 'size': 44003}
# │       └──  {'dirname': 'jstfcllw', 'size': 48099}
# │           └──  {'filename': 'fcfnptrl', 'size': 48099}
# ├──  {'dirname': 'llpmvt', 'size': 736290}
# │   ├──  {'filename': 'llpmvt', 'size': 179597}
# │   └──  {'dirname': 'ndn', 'size': 556693}
# │       ├──  {'filename': 'btsc.zmc', 'size': 220080}
# │       ├──  {'filename': 'hhz', 'size': 190391}
# │       ├──  {'filename': 'jvlfb', 'size': 113172}
# │       └──  {'filename': 'wnwgz.qjp', 'size': 33050}
# ├──  {'dirname': 'tgmt', 'size': 97940}
# │   ├──  {'filename': 'lml.dnh', 'size': 53361}
# │   └──  {'filename': 'psgvcrdd', 'size': 44579}
# └──  {'dirname': 'wcbq', 'size': 4197910}
#     ├──  {'filename': 'qgh.qnh', 'size': 182848}
#     ├──  {'dirname': 'bjnvmpc', 'size': 1353869}
#     │   ├──  {'filename': 'bbzdcqf', 'size': 224127}
#     │   ├──  {'filename': 'bjnvmpc.zhg', 'size': 267019}
#     │   ├──  {'filename': 'dspvfhr.mmh', 'size': 263703}
#     │   ├──  {'filename': 'ntsqzpp.lnl', 'size': 3983}
#     │   ├──  {'dirname': 'glwzwcvm', 'size': 335211}
#     │   │   ├──  {'filename': 'bjnvmpc.zsj', 'size': 167421}
#     │   │   └──  {'dirname': 'llpmvt', 'size': 167790}
#     │   │       └──  {'filename': 'llpmvt.jhw', 'size': 167790}
#     │   ├──  {'dirname': 'hrjjrrvl', 'size': 94221}
#     │   │   ├──  {'filename': 'crlfnccb.svl', 'size': 91994}
#     │   │   └──  {'filename': 'swffpq.nnc', 'size': 2227}
#     │   └──  {'dirname': 'nqbrm', 'size': 165605}
#     │       └──  {'filename': 'rpglpmr.zbh', 'size': 165605}
#     ├──  {'dirname': 'cnwczqp', 'size': 775017}
#     │   ├──  {'dirname': 'cfdn', 'size': 639730}
#     │   │   ├──  {'filename': 'gsmhfr', 'size': 163111}
#     │   │   ├──  {'dirname': 'bjnvmpc', 'size': 257093}
#     │   │   │   └──  {'filename': 'jstfcllw', 'size': 257093}
#     │   │   └──  {'dirname': 'phtt', 'size': 219526}
#     │   │       └──  {'filename': 'bgvm.mnq', 'size': 219526}
#     │   └──  {'dirname': 'jdh', 'size': 135287}
#     │       └──  {'dirname': 'wjzzvs', 'size': 135287}
#     │           └──  {'filename': 'rpglpmr.zbh', 'size': 135287}
#     ├──  {'dirname': 'dpgwtwp', 'size': 529591}
#     │   └──  {'dirname': 'vmwvpjn', 'size': 529591}
#     │       ├──  {'filename': 'hdcb.dhp', 'size': 86191}
#     │       ├──  {'filename': 'jstfcllw.tdd', 'size': 140007}
#     │       ├──  {'filename': 'npbmlv.zst', 'size': 128243}
#     │       └──  {'dirname': 'bjnvmpc', 'size': 175150}
#     │           ├──  {'filename': 'grgj', 'size': 8694}
#     │           └──  {'filename': 'pnrbvd.hdn', 'size': 166456}
#     ├──  {'dirname': 'gtsf', 'size': 1186199}
#     │   ├──  {'filename': 'bjnvmpc', 'size': 231856}
#     │   ├──  {'filename': 'bmm.vwc', 'size': 225380}
#     │   ├──  {'filename': 'wnwgz.qjp', 'size': 279010}
#     │   ├──  {'dirname': 'llpmvt', 'size': 302440}
#     │   │   ├──  {'filename': 'nhbpmvb.pgn', 'size': 143990}
#     │   │   └──  {'dirname': 'pnrbvd', 'size': 158450}
#     │   │       └──  {'filename': 'ghjlw', 'size': 158450}
#     │   └──  {'dirname': 'pqm', 'size': 147513}
#     │       └──  {'filename': 'grgj', 'size': 147513}
#     └──  {'dirname': 'nmsvc', 'size': 170386}
#         └──  {'dirname': 'znlgg', 'size': 170386}
#             └──  {'filename': 'djdv.gbf', 'size': 170386}

# %%
# def compute_dirsizes(dirnode):
#     total_file_size = 0
#     dirlist = []
#     for subnode in PostOrderIter(dirnode):
#         if 'size' in subnode.name.keys():
#             total_file_size += subnode.name['size']
#         if 'dirname' in subnode.name.keys():
#             if subnode is not dirnode:
#                 subdirsize = compute_dirsizes(subnode)
#                 total_file_size += subdirsize
#                 dirlist.append({subnode.name['dirname']: subdirsize})
#     return total_file_size

dirs = {}
for subnode in PostOrderIter(root):
    if 'dirname' in subnode.name.keys():
        dirs[subnode.name['dirname']] = subnode.name['size']

# %%
dirs
# Out:
# {'prwm': 269910,
#  'plldwn': 805305,
#  'pnrbvd': 158450,
#  'rtpjd': 164458,
#  'shvplq': 643876,
#  'mnm': 1695866,
#  'gfjts': 236177,
#  'hqlmzshr': 228388,
#  'smqzqrm': 170034,
#  'bjnvmpc': 175150,
#  'fmjlrc': 169343,
#  'jstfcllw': 48099,
#  'hbfbvdr': 36586,
#  'tlsd': 78854,
#  'dbglngc': 369011,
#  'rdb': 102680,
#  'ddjpm': 385070,
#  'rdmgrtzl': 28086,
#  'ggpctlh': 132279,
#  'fmtpwm': 290358,
#  'jtqgbwhb': 1912274,
#  'lqrf': 26615,
#  'nmsvc': 170386,
#  'wnvtfmfw': 109078,
#  'swvlpql': 457542,
#  'wmm': 285836,
#  'vjrdcjbr': 743378,
#  'qjgbt': 743378,
#  'bqjczmcr': 19020,
#  'brhvhl': 255839,
#  'nfb': 656697,
#  'pfqv': 155078,
#  'mtctn': 1042330,
#  'drjzphm': 188844,
#  'ggjrm': 188844,
#  'bhdpfpb': 78642,
#  'pvz': 194879,
#  'qntnwf': 225789,
#  'llpmvt': 302440,
#  'rjcpn': 1715364,
#  'scpwzh': 270091,
#  'tbrccw': 1254413,
#  'gjtj': 74258,
#  'wrwsn': 191813,
#  'bgvjb': 780932,
#  'ntmfpmr': 266774,
#  'bbpq': 125821,
#  'zpjqjtsl': 112507,
#  'shgtbbfw': 112507,
#  'fwmvpthq': 2676851,
#  'hchfn': 332934,
#  'gdfwttff': 40626,
#  'njptwz': 69007,
#  'zcvn': 157128,
#  'mpz': 419918,
#  'qpvnfl': 234947,
#  'hlwjtqzj': 9887,
#  'wvg': 200935,
#  'rmrngqdg': 648267,
#  'rstzf': 10438530,
#  'ltqjb': 11347870,
#  'zmsbdc': 204067,
#  'zzmpts': 204067,
#  'tmrn': 930256,
#  'bqvdvllf': 216038,
#  'ghdlvvfs': 277273,
#  'ntmmcjh': 267092,
#  'rvwjl': 592657,
#  'vzvwphz': 1456522,
#  'rgbdq': 765240,
#  'cwdpn': 19935440,
#  'mzfzzgsv': 237212,
#  'drzllllv': 446356,
#  'jzlgzd': 223773,
#  'jzwwgjh': 80522,
#  'bzrfbfp': 34834,
#  'rbq': 91779,
#  'bfj': 195345,
#  'nbfsjvzn': 201923,
#  'jcj': 189962,
#  'btpqsr': 750618,
#  'hjgphwdc': 72389,
#  'bnqwnmg': 281017,
#  'ljjmwc': 239040,
#  'vwpsrq': 826832,
#  'fsgn': 2279622,
#  'lwmccr': 166022,
#  'gnj': 188603,
#  'nprpdwj': 149966,
#  'pwg': 45034,
#  'zswbcbpz': 399020,
#  'hpp': 1056414,
#  'svzhc': 1737964,
#  'vblpsfqz': 54358,
#  'qhn': 4720888,
#  'rphmrdnc': 189190,
#  'vnjvqs': 254178,
#  'cblp': 131189,
#  'mvgjj': 215880,
#  'zqgmm': 432590,
#  'nfh': 7564854,
#  'pqtgln': 243775,
#  'fqflwvh': 8582270,
#  'bhwgcrm': 257143,
#  'jczm': 257143,
#  'rrdzzgtg': 43707,
#  'ftlf': 43707,
#  'qtsrhfv': 94962,
#  'fcbs': 94962,
#  'gdjshcz': 57871,
#  'fdz': 254070,
#  'nqrwdstp': 254070,
#  'ngl': 254070,
#  'gtrdds': 254070,
#  'nhwvgjcq': 245064,
#  'sbsqrg': 39334,
#  'rhzsnr': 2045942,
#  'tfsgzdsl': 263522,
#  'ccbn': 1111607,
#  'btjdllpn': 136706,
#  'zgt': 44873,
#  'fnnjdr': 3543448,
#  'pszldqqh': 89993,
#  'wdlp': 450070,
#  'lpbrvhw': 870884,
#  'jsnfn': 30250,
#  'smhjmb': 334791,
#  'dqqcgn': 253086,
#  'jdssgdpv': 234151,
#  'wwvlv': 92102,
#  'lhltq': 1768126,
#  'ndn': 556693,
#  'tgmt': 97940,
#  'glwzwcvm': 335211,
#  'hrjjrrvl': 94221,
#  'nqbrm': 165605,
#  'phtt': 219526,
#  'cfdn': 639730,
#  'wjzzvs': 135287,
#  'jdh': 135287,
#  'cnwczqp': 775017,
#  'vmwvpjn': 529591,
#  'dpgwtwp': 529591,
#  'pqm': 147513,
#  'gtsf': 1186199,
#  'znlgg': 170386,
#  'wcbq': 4197910,
#  '/': 41072511}

# %%
answer = 0
for name, dirsize in dirs.items():
    if dirsize <= 100000:
        print(f"Include: {dirsize:8d} {name}")
        answer += dirsize
print("answer: ", answer)
# Out:
# Include:    48099 jstfcllw
# Include:    36586 hbfbvdr
# Include:    78854 tlsd
# Include:    28086 rdmgrtzl
# Include:    26615 lqrf
# Include:    19020 bqjczmcr
# Include:    78642 bhdpfpb
# Include:    74258 gjtj
# Include:    40626 gdfwttff
# Include:    69007 njptwz
# Include:     9887 hlwjtqzj
# Include:    80522 jzwwgjh
# Include:    34834 bzrfbfp
# Include:    91779 rbq
# Include:    72389 hjgphwdc
# Include:    45034 pwg
# Include:    54358 vblpsfqz
# Include:    43707 rrdzzgtg
# Include:    43707 ftlf
# Include:    94962 qtsrhfv
# Include:    94962 fcbs
# Include:    57871 gdjshcz
# Include:    39334 sbsqrg
# Include:    44873 zgt
# Include:    89993 pszldqqh
# Include:    30250 jsnfn
# Include:    92102 wwvlv
# Include:    97940 tgmt
# Include:    94221 hrjjrrvl
# answer:  1712518
